# %%
import tensorflow.compat.v1 as tf
import numpy as np
import urllib
tf.compat.v1.disable_eager_execution()

# %%
# the number of iterations to train for
numTrainingIters = 10000

# the number of hidden neurons that hold the state of the RNN
hiddenUnits = 1000

# the number of classes that we are learning over
numClasses = 3

# the number of data points in a batch
batchSize = 100

# %%
# this function takes a dictionary (called data) which contains
# of (dataPointID, (classNumber, matrix)) entries.  Each matrix
# is a sequence of vectors; each vector has a one-hot-encoding of
# an ascii character, and the sequence of vectors corresponds to
# one line of text.  classNumber indicates which file the line of
# text came from.
#
# The argument maxSeqLen is the maximum length of a line of text
# seen so far.  fileName is the name of a file whose contents
# we want to add to data.  classNum is an indicator of the class
# we are going to associate with text from that file.  linesToUse
# tells us how many lines to sample from the file.
#
# The return val is the new maxSeqLen, as well as the new data
# dictionary with the additional lines of text added
def addToData (maxSeqLen, data, fileName, classNum, linesToUse):
    #
    # open the file and read it in
    response = urllib.request.urlopen(fileName)
    content = response.readlines ()
    #
    # sample linesToUse numbers; these will tell us what lines
    # from the text file we will use
    myInts = np.random.randint (0, len(content), linesToUse)
    #
    # i is the key of the next line of text to add to the dictionary
    i = len(data)
    #
    # loop thru and add the lines of text to the dictionary
    for whichLine in myInts.flat:
        #
        # get the line and ignore it if it has nothing in it
        line = content[whichLine].decode("utf-8")
        if line.isspace () or len(line) == 0:
            continue;
        #
        # take note if this is the longest line we've seen
        if len (line) > maxSeqLen:
            maxSeqLen = len (line)
        #
        # create the matrix that will hold this line
        temp = np.zeros((len(line), 256))
        #
        # j is the character we are on
        j = 0
        #
        # loop thru the characters
        for ch in line:
            #
            # non-ascii? ignore
            if ord(ch) >= 256:
                continue
            #
            # one hot!
            temp[j][ord(ch)] = 1
            #
            # move onto the next character
            j = j + 1
            #
        # remember the line of text
        data[i] = (classNum, temp)
        #
        # move onto the next line
        i = i + 1
    #
    # and return the dictionary with the new data
    return (maxSeqLen, data)

# %%
# this function takes as input a data set encoded as a dictionary
# (same encoding as the last function) and pre-pends every line of
# text with empty characters so that each line of text is exactly
# maxSeqLen characters in size
def pad (maxSeqLen, data):
   #
   # loop thru every line of text
   for i in data:
        #
        # access the matrix and the label
        temp = data[i][1]
        label = data[i][0]
        #
        # get the number of chatacters in this line
        len = temp.shape[0]
        #
        # and then pad so the line is the correct length
        padding = np.zeros ((maxSeqLen - len,256))
        data[i] = (label, np.transpose (np.concatenate ((padding, temp), axis = 0)))
   #
   # return the new data set
   return data

# %%
# this generates a new batch of training data of size batchSize from the
# list of lines of text data. This version of generateData is useful for
# an RNN because the data set x is a NumPy array with dimensions
# [batchSize, 256, maxSeqLen]; it can be unstacked into a series of
# matrices containing one-hot character encodings for each data point
# using tf.unstack(inputX, axis=2)
def generateDataRNN (maxSeqLen, data):
    #
    # randomly sample batchSize lines of text
    myInts = np.random.randint (0, len(data), batchSize)
    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack ([data[i][1] for i in myInts.flat])
    #
    # and stack all of the labels into a vector of labels
    y = np.stack ([np.array((data[i][0])) for i in myInts.flat])
    #
    # return the pair
    return (x, y)

# %%
# this also generates a new batch of training data, but it represents
# the data as a NumPy array with dimensions [batchSize, 256 * maxSeqLen]
# where for each data point, all characters have been appended.  Useful
# for feed-forward network training
def generateDataFeedForward (maxSeqLen, data):
    #
    # randomly sample batchSize lines of text
    myInts = np.random.randint (0, len(data), batchSize)
    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack (data[i][1].flatten () for i in myInts.flat)
    #
    # and stack all of the labels into a vector of labels
    y = np.stack (np.array((data[i][0])) for i in myInts.flat)
    #
    # return the pair
    return (x, y)

# %%
# create the data dictionary
maxSeqLen = 0
data = {}

# load up the three data sets
(maxSeqLen, data) = addToData (maxSeqLen, data, "https://s3.amazonaws.com/chrisjermainebucket/text/Holmes.txt", 0, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "https://s3.amazonaws.com/chrisjermainebucket/text/war.txt", 1, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "https://s3.amazonaws.com/chrisjermainebucket/text/william.txt", 2, 10000)

# pad each entry in the dictionary with empty characters as needed so
# that the sequences are all of the same length
data = pad (maxSeqLen, data)

# now we build the TensorFlow computation... there are two inputs,
# a batch of text lines and a batch of labels
inputX = tf.placeholder(tf.float32, [batchSize, 256, maxSeqLen])
inputY = tf.placeholder(tf.int32, [batchSize])

# this is the inital state of the RNN, before processing any data
initialState = tf.placeholder(tf.float32, [batchSize, hiddenUnits])

# the weight matrix that maps the inputs and hidden state to a set of values
Wfir = tf.Variable(np.random.normal(0, 0.01, (hiddenUnits + 256, hiddenUnits)), dtype=tf.float32)
Wsec = tf.Variable(np.random.normal(0, 0.01, (hiddenUnits, hiddenUnits)), dtype=tf.float32)

# weights and bias for the final classification
W2 = tf.Variable(np.random.normal (0, 0.05, (hiddenUnits, numClasses)),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,numClasses)), dtype=tf.float32)

# unpack the input sequences so that we have a series of matrices,
# each of which has a one-hot encoding of the current character from
# every input sequence
sequenceOfLetters = tf.unstack(inputX, axis=2)

# now we implement the forward pass
currentState = initialState
for timeTick in sequenceOfLetters:
    #
    # concatenate the state with the input, then compute the next state
    inputPlusState = tf.concat([timeTick, currentState], 1)
    next_state = tf.tanh(tf.matmul(inputPlusState, Wfir))
    last_state = tf.tanh(tf.matmul(next_state, Wsec))
    currentState = last_state

# compute the set of outputs
outputs = tf.matmul(currentState, W2) + b2

predictions = tf.nn.softmax(outputs)

# compute the loss
losses = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=outputs, labels=inputY)
totalLoss = tf.reduce_mean(losses)

# use gradient descent to train
trainingAlg = tf.compat.v1.train.AdagradOptimizer(0.01).minimize(totalLoss)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/training/adagrad.py:138: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# and train!!
with tf.Session() as sess:
    #
    # initialize everything
    sess.run(tf.compat.v1.global_variables_initializer())
    #
    # and run the training iters
    for epoch in range(numTrainingIters):
        #
        # get some data
        x, y = generateDataRNN (maxSeqLen, data)
        #
        # do the training epoch
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _trainingAlg, _currentState, _predictions, _outputs = sess.run(
                [totalLoss, trainingAlg, currentState, predictions, outputs],
                feed_dict={
                    inputX:x,
                    inputY:y,
                    initialState:_currentState
                })
        #
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y)):
           maxPos = -1
           maxVal = 0.0
           for j in range (numClasses):
               if maxVal < _predictions[i][j]:
                   maxVal = _predictions[i][j]
                   maxPos = j
           if maxPos == y[i]:
               numCorrect = numCorrect + 1
        #
        # print out to the screen
        print("Step", epoch, "Loss", _totalLoss, "Correct", numCorrect, "out of", batchSize)
# Out:
# Streaming output truncated to the last 5000 lines.
# Step 5000 Loss 1.0927461 Correct 38 out of 100
# Step 5001 Loss 1.0751871 Correct 48 out of 100
# Step 5002 Loss 1.0987583 Correct 35 out of 100
# Step 5003 Loss 1.0823455 Correct 44 out of 100
# Step 5004 Loss 1.0840809 Correct 43 out of 100
# Step 5005 Loss 1.1025014 Correct 33 out of 100
# Step 5006 Loss 1.0912795 Correct 39 out of 100
# Step 5007 Loss 1.0915272 Correct 39 out of 100
# Step 5008 Loss 1.1061966 Correct 31 out of 100
# Step 5009 Loss 1.1042526 Correct 32 out of 100
# Step 5010 Loss 1.1095018 Correct 29 out of 100
# Step 5011 Loss 1.0987644 Correct 35 out of 100
# Step 5012 Loss 1.0790881 Correct 46 out of 100
# Step 5013 Loss 1.0930675 Correct 38 out of 100
# Step 5014 Loss 1.0788958 Correct 46 out of 100
# Step 5015 Loss 1.0840585 Correct 43 out of 100
# Step 5016 Loss 1.091182 Correct 39 out of 100
# Step 5017 Loss 1.0913222 Correct 39 out of 100
# Step 5018 Loss 1.1044114 Correct 32 out of 100
# Step 5019 Loss 1.0875294 Correct 41 out of 100
# Step 5020 Loss 1.0856378 Correct 42 out of 100
# Step 5021 Loss 1.1009369 Correct 34 out of 100
# Step 5022 Loss 1.0893157 Correct 40 out of 100
# Step 5023 Loss 1.1098862 Correct 29 out of 100
# Step 5024 Loss 1.0986906 Correct 35 out of 100
# Step 5025 Loss 1.0929954 Correct 38 out of 100
# Step 5026 Loss 1.1005627 Correct 34 out of 100
# Step 5027 Loss 1.1041694 Correct 32 out of 100
# Step 5028 Loss 1.0999936 Correct 34 out of 100
# Step 5029 Loss 1.0930727 Correct 38 out of 100
# Step 5030 Loss 1.1039582 Correct 32 out of 100
# Step 5031 Loss 1.1057088 Correct 31 out of 100
# Step 5032 Loss 1.0893937 Correct 40 out of 100
# Step 5033 Loss 1.0810896 Correct 45 out of 100
# Step 5034 Loss 1.1028262 Correct 33 out of 100
# Step 5035 Loss 1.1015207 Correct 33 out of 100
# Step 5036 Loss 1.0934715 Correct 38 out of 100
# Step 5037 Loss 1.0850198 Correct 43 out of 100
# Step 5038 Loss 1.0931087 Correct 38 out of 100
# Step 5039 Loss 1.1021681 Correct 33 out of 100
# Step 5040 Loss 1.0946425 Correct 37 out of 100
# Step 5041 Loss 1.0916647 Correct 39 out of 100
# Step 5042 Loss 1.0933667 Correct 38 out of 100
# Step 5043 Loss 1.0895251 Correct 40 out of 100
# Step 5044 Loss 1.0845945 Correct 43 out of 100
# Step 5045 Loss 1.082456 Correct 44 out of 100
# Step 5046 Loss 1.0894645 Correct 40 out of 100
# Step 5047 Loss 1.0855446 Correct 42 out of 100
# Step 5048 Loss 1.1025312 Correct 33 out of 100
# Step 5049 Loss 1.1080414 Correct 30 out of 100
# Step 5050 Loss 1.0987542 Correct 35 out of 100
# Step 5051 Loss 1.0966262 Correct 36 out of 100
# Step 5052 Loss 1.0933095 Correct 38 out of 100
# Step 5053 Loss 1.1005219 Correct 34 out of 100
# Step 5054 Loss 1.0898297 Correct 40 out of 100
# Step 5055 Loss 1.1038536 Correct 32 out of 100
# Step 5056 Loss 1.0878018 Correct 41 out of 100
# Step 5057 Loss 1.1016054 Correct 33 out of 100
# Step 5058 Loss 1.1091388 Correct 29 out of 100
# Step 5059 Loss 1.0950389 Correct 37 out of 100
# Step 5060 Loss 1.1014954 Correct 33 out of 100
# Step 5061 Loss 1.0793139 Correct 46 out of 100
# Step 5062 Loss 1.1105613 Correct 28 out of 100
# Step 5063 Loss 1.0963616 Correct 36 out of 100
# Step 5064 Loss 1.073873 Correct 49 out of 100
# Step 5065 Loss 1.1050811 Correct 31 out of 100
# Step 5066 Loss 1.0864663 Correct 42 out of 100
# Step 5067 Loss 1.0840008 Correct 43 out of 100
# Step 5068 Loss 1.089828 Correct 40 out of 100
# Step 5069 Loss 1.092663 Correct 38 out of 100
# Step 5070 Loss 1.0973836 Correct 36 out of 100
# Step 5071 Loss 1.0730247 Correct 49 out of 100
# Step 5072 Loss 1.0884752 Correct 41 out of 100
# Step 5073 Loss 1.081648 Correct 44 out of 100
# Step 5074 Loss 1.0856299 Correct 42 out of 100
# Step 5075 Loss 1.1075945 Correct 30 out of 100
# Step 5076 Loss 1.1115426 Correct 28 out of 100
# Step 5077 Loss 1.09643 Correct 36 out of 100
# Step 5078 Loss 1.0930095 Correct 39 out of 100
# Step 5079 Loss 1.1061729 Correct 31 out of 100
# Step 5080 Loss 1.1137625 Correct 27 out of 100
# Step 5081 Loss 1.0864148 Correct 42 out of 100
# Step 5082 Loss 1.0855523 Correct 42 out of 100
# Step 5083 Loss 1.0967782 Correct 36 out of 100
# Step 5084 Loss 1.0968741 Correct 36 out of 100
# Step 5085 Loss 1.0958917 Correct 36 out of 100
# Step 5086 Loss 1.0968815 Correct 36 out of 100
# Step 5087 Loss 1.0996029 Correct 34 out of 100
# Step 5088 Loss 1.0998195 Correct 34 out of 100
# Step 5089 Loss 1.1000098 Correct 34 out of 100
# Step 5090 Loss 1.0737754 Correct 49 out of 100
# Step 5091 Loss 1.1160097 Correct 25 out of 100
# Step 5092 Loss 1.0894226 Correct 40 out of 100
# Step 5093 Loss 1.0921161 Correct 39 out of 100
# Step 5094 Loss 1.1074979 Correct 29 out of 100
# Step 5095 Loss 1.0912036 Correct 39 out of 100
# Step 5096 Loss 1.088634 Correct 40 out of 100
# Step 5097 Loss 1.0990189 Correct 35 out of 100
# Step 5098 Loss 1.096329 Correct 36 out of 100
# Step 5099 Loss 1.0950238 Correct 37 out of 100
# Step 5100 Loss 1.1072272 Correct 30 out of 100
# Step 5101 Loss 1.0963806 Correct 36 out of 100
# Step 5102 Loss 1.0960847 Correct 36 out of 100
# Step 5103 Loss 1.0904385 Correct 40 out of 100
# Step 5104 Loss 1.0971116 Correct 37 out of 100
# Step 5105 Loss 1.0918261 Correct 39 out of 100
# Step 5106 Loss 1.0896285 Correct 40 out of 100
# Step 5107 Loss 1.0984262 Correct 35 out of 100
# Step 5108 Loss 1.103766 Correct 32 out of 100
# Step 5109 Loss 1.1032661 Correct 32 out of 100
# Step 5110 Loss 1.1091781 Correct 28 out of 100
# Step 5111 Loss 1.0821718 Correct 45 out of 100
# Step 5112 Loss 1.0849526 Correct 43 out of 100
# Step 5113 Loss 1.0949101 Correct 37 out of 100
# Step 5114 Loss 1.1017003 Correct 33 out of 100
# Step 5115 Loss 1.1155508 Correct 25 out of 100
# Step 5116 Loss 1.1030375 Correct 32 out of 100
# Step 5117 Loss 1.0801544 Correct 46 out of 100
# Step 5118 Loss 1.0866807 Correct 42 out of 100
# Step 5119 Loss 1.0989156 Correct 35 out of 100
# Step 5120 Loss 1.0934476 Correct 37 out of 100
# Step 5121 Loss 1.0963161 Correct 36 out of 100
# Step 5122 Loss 1.084537 Correct 43 out of 100
# Step 5123 Loss 1.0942459 Correct 37 out of 100
# Step 5124 Loss 1.0921079 Correct 38 out of 100
# Step 5125 Loss 1.0953783 Correct 37 out of 100
# Step 5126 Loss 1.1042109 Correct 32 out of 100
# Step 5127 Loss 1.0941426 Correct 38 out of 100
# Step 5128 Loss 1.0859119 Correct 42 out of 100
# Step 5129 Loss 1.0800872 Correct 46 out of 100
# Step 5130 Loss 1.1023221 Correct 33 out of 100
# Step 5131 Loss 1.093475 Correct 38 out of 100
# Step 5132 Loss 1.0889406 Correct 40 out of 100
# Step 5133 Loss 1.0972416 Correct 36 out of 100
# Step 5134 Loss 1.1077598 Correct 29 out of 100
# Step 5135 Loss 1.0865588 Correct 42 out of 100
# Step 5136 Loss 1.0994276 Correct 34 out of 100
# Step 5137 Loss 1.1136721 Correct 26 out of 100
# Step 5138 Loss 1.0928233 Correct 37 out of 100
# Step 5139 Loss 1.0933951 Correct 38 out of 100
# Step 5140 Loss 1.0956626 Correct 37 out of 100
# Step 5141 Loss 1.0781481 Correct 47 out of 100
# Step 5142 Loss 1.1035662 Correct 31 out of 100
# Step 5143 Loss 1.094843 Correct 38 out of 100
# Step 5144 Loss 1.0933294 Correct 37 out of 100
# Step 5145 Loss 1.1015033 Correct 33 out of 100
# Step 5146 Loss 1.1066436 Correct 29 out of 100
# Step 5147 Loss 1.0923892 Correct 39 out of 100
# Step 5148 Loss 1.0920177 Correct 39 out of 100
# Step 5149 Loss 1.0979421 Correct 36 out of 100
# Step 5150 Loss 1.0875858 Correct 41 out of 100
# Step 5151 Loss 1.1132787 Correct 26 out of 100
# Step 5152 Loss 1.1031561 Correct 33 out of 100
# Step 5153 Loss 1.0839522 Correct 44 out of 100
# Step 5154 Loss 1.0986038 Correct 35 out of 100
# Step 5155 Loss 1.0950624 Correct 37 out of 100
# Step 5156 Loss 1.1006697 Correct 34 out of 100
# Step 5157 Loss 1.0999184 Correct 33 out of 100
# Step 5158 Loss 1.106592 Correct 30 out of 100
# Step 5159 Loss 1.0907615 Correct 39 out of 100
# Step 5160 Loss 1.0859379 Correct 42 out of 100
# Step 5161 Loss 1.0956951 Correct 36 out of 100
# Step 5162 Loss 1.0969623 Correct 35 out of 100
# Step 5163 Loss 1.0933633 Correct 38 out of 100
# Step 5164 Loss 1.0872893 Correct 42 out of 100
# Step 5165 Loss 1.093421 Correct 38 out of 100
# Step 5166 Loss 1.0806073 Correct 45 out of 100
# Step 5167 Loss 1.1034503 Correct 31 out of 100
# Step 5168 Loss 1.1041944 Correct 31 out of 100
# Step 5169 Loss 1.0972193 Correct 36 out of 100
# Step 5170 Loss 1.0966114 Correct 35 out of 100
# Step 5171 Loss 1.0970352 Correct 35 out of 100
# Step 5172 Loss 1.1017833 Correct 33 out of 100
# Step 5173 Loss 1.0953858 Correct 37 out of 100
# Step 5174 Loss 1.0871588 Correct 41 out of 100
# Step 5175 Loss 1.0931727 Correct 38 out of 100
# Step 5176 Loss 1.0870647 Correct 42 out of 100
# Step 5177 Loss 1.0962777 Correct 36 out of 100
# Step 5178 Loss 1.1023263 Correct 34 out of 100
# Step 5179 Loss 1.1011626 Correct 32 out of 100
# Step 5180 Loss 1.0904442 Correct 41 out of 100
# Step 5181 Loss 1.1084358 Correct 29 out of 100
# Step 5182 Loss 1.0994334 Correct 34 out of 100
# Step 5183 Loss 1.1027919 Correct 32 out of 100
# Step 5184 Loss 1.0815595 Correct 46 out of 100
# Step 5185 Loss 1.1045516 Correct 32 out of 100
# Step 5186 Loss 1.0914017 Correct 40 out of 100
# Step 5187 Loss 1.086607 Correct 43 out of 100
# Step 5188 Loss 1.0988389 Correct 35 out of 100
# Step 5189 Loss 1.098672 Correct 34 out of 100
# Step 5190 Loss 1.1003802 Correct 33 out of 100
# Step 5191 Loss 1.087729 Correct 41 out of 100
# Step 5192 Loss 1.09137 Correct 39 out of 100
# Step 5193 Loss 1.0861245 Correct 42 out of 100
# Step 5194 Loss 1.088729 Correct 41 out of 100
# Step 5195 Loss 1.0970649 Correct 36 out of 100
# Step 5196 Loss 1.1054155 Correct 31 out of 100
# Step 5197 Loss 1.1065145 Correct 30 out of 100
# Step 5198 Loss 1.1030196 Correct 32 out of 100
# Step 5199 Loss 1.1062115 Correct 29 out of 100
# Step 5200 Loss 1.0994415 Correct 34 out of 100
# Step 5201 Loss 1.0987622 Correct 35 out of 100
# Step 5202 Loss 1.0847793 Correct 44 out of 100
# Step 5203 Loss 1.1004583 Correct 33 out of 100
# Step 5204 Loss 1.10023 Correct 33 out of 100
# Step 5205 Loss 1.104719 Correct 31 out of 100
# Step 5206 Loss 1.0947269 Correct 37 out of 100
# Step 5207 Loss 1.0915561 Correct 39 out of 100
# Step 5208 Loss 1.0832978 Correct 43 out of 100
# Step 5209 Loss 1.0911453 Correct 40 out of 100
# Step 5210 Loss 1.0991368 Correct 36 out of 100
# Step 5211 Loss 1.088964 Correct 41 out of 100
# Step 5212 Loss 1.0931487 Correct 38 out of 100
# Step 5213 Loss 1.1009867 Correct 34 out of 100
# Step 5214 Loss 1.0929791 Correct 39 out of 100
# Step 5215 Loss 1.0965526 Correct 36 out of 100
# Step 5216 Loss 1.0859599 Correct 43 out of 100
# Step 5217 Loss 1.0955313 Correct 36 out of 100
# Step 5218 Loss 1.094534 Correct 37 out of 100
# Step 5219 Loss 1.1024485 Correct 32 out of 100
# Step 5220 Loss 1.0892998 Correct 41 out of 100
# Step 5221 Loss 1.0882349 Correct 41 out of 100
# Step 5222 Loss 1.1015258 Correct 32 out of 100
# Step 5223 Loss 1.0806565 Correct 46 out of 100
# Step 5224 Loss 1.0928385 Correct 38 out of 100
# Step 5225 Loss 1.086218 Correct 43 out of 100
# Step 5226 Loss 1.083881 Correct 44 out of 100
# Step 5227 Loss 1.0923761 Correct 38 out of 100
# Step 5228 Loss 1.0901066 Correct 40 out of 100
# Step 5229 Loss 1.0929445 Correct 38 out of 100
# Step 5230 Loss 1.0942848 Correct 37 out of 100
# Step 5231 Loss 1.0935386 Correct 37 out of 100
# Step 5232 Loss 1.0919846 Correct 38 out of 100
# Step 5233 Loss 1.1066263 Correct 29 out of 100
# Step 5234 Loss 1.1065834 Correct 29 out of 100
# Step 5235 Loss 1.1005073 Correct 33 out of 100
# Step 5236 Loss 1.0857949 Correct 43 out of 100
# Step 5237 Loss 1.1014633 Correct 32 out of 100
# Step 5238 Loss 1.0984082 Correct 35 out of 100
# Step 5239 Loss 1.0830218 Correct 44 out of 100
# Step 5240 Loss 1.0881414 Correct 42 out of 100
# Step 5241 Loss 1.1022335 Correct 33 out of 100
# Step 5242 Loss 1.1062436 Correct 30 out of 100
# Step 5243 Loss 1.0966758 Correct 36 out of 100
# Step 5244 Loss 1.0944239 Correct 38 out of 100
# Step 5245 Loss 1.086413 Correct 42 out of 100
# Step 5246 Loss 1.0958251 Correct 36 out of 100
# Step 5247 Loss 1.098771 Correct 35 out of 100
# Step 5248 Loss 1.1070269 Correct 30 out of 100
# Step 5249 Loss 1.1023726 Correct 33 out of 100
# Step 5250 Loss 1.0906291 Correct 40 out of 100
# Step 5251 Loss 1.0933871 Correct 38 out of 100
# Step 5252 Loss 1.0848101 Correct 43 out of 100
# Step 5253 Loss 1.0903747 Correct 40 out of 100
# Step 5254 Loss 1.0764064 Correct 48 out of 100
# Step 5255 Loss 1.0969441 Correct 36 out of 100
# Step 5256 Loss 1.1010181 Correct 34 out of 100
# Step 5257 Loss 1.0826497 Correct 45 out of 100
# Step 5258 Loss 1.0945566 Correct 37 out of 100
# Step 5259 Loss 1.0982689 Correct 35 out of 100
# Step 5260 Loss 1.0887558 Correct 41 out of 100
# Step 5261 Loss 1.0965595 Correct 36 out of 100
# Step 5262 Loss 1.0821787 Correct 44 out of 100
# Step 5263 Loss 1.1147767 Correct 25 out of 100
# Step 5264 Loss 1.0945976 Correct 37 out of 100
# Step 5265 Loss 1.0945067 Correct 37 out of 100
# Step 5266 Loss 1.0936466 Correct 37 out of 100
# Step 5267 Loss 1.102248 Correct 33 out of 100
# Step 5268 Loss 1.1068037 Correct 30 out of 100
# Step 5269 Loss 1.0856509 Correct 43 out of 100
# Step 5270 Loss 1.1068312 Correct 29 out of 100
# Step 5271 Loss 1.0894629 Correct 40 out of 100
# Step 5272 Loss 1.0980096 Correct 35 out of 100
# Step 5273 Loss 1.1048797 Correct 31 out of 100
# Step 5274 Loss 1.1026093 Correct 32 out of 100
# Step 5275 Loss 1.0954771 Correct 37 out of 100
# Step 5276 Loss 1.103441 Correct 32 out of 100
# Step 5277 Loss 1.0879806 Correct 41 out of 100
# Step 5278 Loss 1.0759931 Correct 49 out of 100
# Step 5279 Loss 1.0869989 Correct 42 out of 100
# Step 5280 Loss 1.0919664 Correct 39 out of 100
# Step 5281 Loss 1.0853504 Correct 43 out of 100
# Step 5282 Loss 1.100358 Correct 34 out of 100
# Step 5283 Loss 1.0881143 Correct 41 out of 100
# Step 5284 Loss 1.0931511 Correct 38 out of 100
# Step 5285 Loss 1.1100705 Correct 28 out of 100
# Step 5286 Loss 1.0957735 Correct 36 out of 100
# Step 5287 Loss 1.1031414 Correct 32 out of 100
# Step 5288 Loss 1.091332 Correct 39 out of 100
# Step 5289 Loss 1.1004001 Correct 33 out of 100
# Step 5290 Loss 1.0965916 Correct 36 out of 100
# Step 5291 Loss 1.0988752 Correct 34 out of 100
# Step 5292 Loss 1.0882099 Correct 41 out of 100
# Step 5293 Loss 1.0980664 Correct 35 out of 100
# Step 5294 Loss 1.1036922 Correct 32 out of 100
# Step 5295 Loss 1.0979605 Correct 35 out of 100
# Step 5296 Loss 1.087812 Correct 41 out of 100
# Step 5297 Loss 1.0783837 Correct 47 out of 100
# Step 5298 Loss 1.0986882 Correct 34 out of 100
# Step 5299 Loss 1.0854012 Correct 43 out of 100
# Step 5300 Loss 1.0985501 Correct 35 out of 100
# Step 5301 Loss 1.0971779 Correct 36 out of 100
# Step 5302 Loss 1.0976418 Correct 35 out of 100
# Step 5303 Loss 1.0936898 Correct 38 out of 100
# Step 5304 Loss 1.095888 Correct 36 out of 100
# Step 5305 Loss 1.1067302 Correct 29 out of 100
# Step 5306 Loss 1.0949426 Correct 38 out of 100
# Step 5307 Loss 1.09792 Correct 35 out of 100
# Step 5308 Loss 1.0961896 Correct 36 out of 100
# Step 5309 Loss 1.1123693 Correct 25 out of 100
# Step 5310 Loss 1.0773515 Correct 48 out of 100
# Step 5311 Loss 1.0928695 Correct 37 out of 100
# Step 5312 Loss 1.1004049 Correct 33 out of 100
# Step 5313 Loss 1.0957642 Correct 36 out of 100
# Step 5314 Loss 1.0818628 Correct 45 out of 100
# Step 5315 Loss 1.0929129 Correct 39 out of 100
# Step 5316 Loss 1.0860984 Correct 42 out of 100
# Step 5317 Loss 1.0920206 Correct 39 out of 100
# Step 5318 Loss 1.1009815 Correct 35 out of 100
# Step 5319 Loss 1.0960836 Correct 37 out of 100
# Step 5320 Loss 1.0927316 Correct 38 out of 100
# Step 5321 Loss 1.0901965 Correct 40 out of 100
# Step 5322 Loss 1.0818889 Correct 45 out of 100
# Step 5323 Loss 1.0986397 Correct 35 out of 100
# Step 5324 Loss 1.1054896 Correct 30 out of 100
# Step 5325 Loss 1.0985827 Correct 35 out of 100
# Step 5326 Loss 1.1040167 Correct 31 out of 100
# Step 5327 Loss 1.0799598 Correct 46 out of 100
# Step 5328 Loss 1.1051915 Correct 31 out of 100
# Step 5329 Loss 1.0902593 Correct 40 out of 100
# Step 5330 Loss 1.0846946 Correct 43 out of 100
# Step 5331 Loss 1.0874777 Correct 41 out of 100
# Step 5332 Loss 1.1048583 Correct 31 out of 100
# Step 5333 Loss 1.0981467 Correct 35 out of 100
# Step 5334 Loss 1.103548 Correct 32 out of 100
# Step 5335 Loss 1.0839386 Correct 44 out of 100
# Step 5336 Loss 1.0876399 Correct 41 out of 100
# Step 5337 Loss 1.0781173 Correct 47 out of 100
# Step 5338 Loss 1.0985389 Correct 35 out of 100
# Step 5339 Loss 1.1129774 Correct 27 out of 100
# Step 5340 Loss 1.0960996 Correct 36 out of 100
# Step 5341 Loss 1.0902207 Correct 40 out of 100
# Step 5342 Loss 1.0928227 Correct 38 out of 100
# Step 5343 Loss 1.0815439 Correct 45 out of 100
# Step 5344 Loss 1.0975076 Correct 35 out of 100
# Step 5345 Loss 1.0944896 Correct 37 out of 100
# Step 5346 Loss 1.0891254 Correct 40 out of 100
# Step 5347 Loss 1.0875444 Correct 41 out of 100
# Step 5348 Loss 1.086288 Correct 42 out of 100
# Step 5349 Loss 1.085798 Correct 42 out of 100
# Step 5350 Loss 1.0933652 Correct 38 out of 100
# Step 5351 Loss 1.0912004 Correct 39 out of 100
# Step 5352 Loss 1.0859511 Correct 42 out of 100
# Step 5353 Loss 1.1062493 Correct 30 out of 100
# Step 5354 Loss 1.0926225 Correct 38 out of 100
# Step 5355 Loss 1.0894507 Correct 40 out of 100
# Step 5356 Loss 1.0995483 Correct 34 out of 100
# Step 5357 Loss 1.0958722 Correct 36 out of 100
# Step 5358 Loss 1.0919139 Correct 39 out of 100
# Step 5359 Loss 1.0911571 Correct 39 out of 100
# Step 5360 Loss 1.0888284 Correct 40 out of 100
# Step 5361 Loss 1.0893635 Correct 40 out of 100
# Step 5362 Loss 1.09375 Correct 37 out of 100
# Step 5363 Loss 1.0940644 Correct 38 out of 100
# Step 5364 Loss 1.0991377 Correct 35 out of 100
# Step 5365 Loss 1.1052934 Correct 31 out of 100
# Step 5366 Loss 1.0949764 Correct 37 out of 100
# Step 5367 Loss 1.1036727 Correct 32 out of 100
# Step 5368 Loss 1.081197 Correct 45 out of 100
# Step 5369 Loss 1.1125329 Correct 27 out of 100
# Step 5370 Loss 1.0792443 Correct 46 out of 100
# Step 5371 Loss 1.0825582 Correct 44 out of 100
# Step 5372 Loss 1.1079488 Correct 30 out of 100
# Step 5373 Loss 1.0949534 Correct 37 out of 100
# Step 5374 Loss 1.0915552 Correct 39 out of 100
# Step 5375 Loss 1.089572 Correct 40 out of 100
# Step 5376 Loss 1.0816678 Correct 44 out of 100
# Step 5377 Loss 1.0830338 Correct 44 out of 100
# Step 5378 Loss 1.0864869 Correct 42 out of 100
# Step 5379 Loss 1.0965692 Correct 36 out of 100
# Step 5380 Loss 1.0908126 Correct 39 out of 100
# Step 5381 Loss 1.1027108 Correct 33 out of 100
# Step 5382 Loss 1.1019864 Correct 33 out of 100
# Step 5383 Loss 1.0916281 Correct 39 out of 100
# Step 5384 Loss 1.0856568 Correct 42 out of 100
# Step 5385 Loss 1.1000589 Correct 34 out of 100
# Step 5386 Loss 1.1004192 Correct 34 out of 100
# Step 5387 Loss 1.0976967 Correct 35 out of 100
# Step 5388 Loss 1.0960008 Correct 36 out of 100
# Step 5389 Loss 1.0963798 Correct 36 out of 100
# Step 5390 Loss 1.0908221 Correct 39 out of 100
# Step 5391 Loss 1.0896362 Correct 40 out of 100
# Step 5392 Loss 1.0958997 Correct 36 out of 100
# Step 5393 Loss 1.1002986 Correct 34 out of 100
# Step 5394 Loss 1.0912241 Correct 39 out of 100
# Step 5395 Loss 1.0877248 Correct 41 out of 100
# Step 5396 Loss 1.0967126 Correct 36 out of 100
# Step 5397 Loss 1.0895404 Correct 40 out of 100
# Step 5398 Loss 1.0879959 Correct 41 out of 100
# Step 5399 Loss 1.0841979 Correct 43 out of 100
# Step 5400 Loss 1.0927715 Correct 38 out of 100
# Step 5401 Loss 1.0838176 Correct 43 out of 100
# Step 5402 Loss 1.0813309 Correct 44 out of 100
# Step 5403 Loss 1.0995256 Correct 34 out of 100
# Step 5404 Loss 1.0983845 Correct 35 out of 100
# Step 5405 Loss 1.0894853 Correct 40 out of 100
# Step 5406 Loss 1.0945281 Correct 37 out of 100
# Step 5407 Loss 1.0918378 Correct 39 out of 100
# Step 5408 Loss 1.0761943 Correct 47 out of 100
# Step 5409 Loss 1.0798506 Correct 45 out of 100
# Step 5410 Loss 1.0978492 Correct 35 out of 100
# Step 5411 Loss 1.0961308 Correct 36 out of 100
# Step 5412 Loss 1.098049 Correct 35 out of 100
# Step 5413 Loss 1.1132936 Correct 27 out of 100
# Step 5414 Loss 1.08926 Correct 40 out of 100
# Step 5415 Loss 1.0933611 Correct 38 out of 100
# Step 5416 Loss 1.0776713 Correct 46 out of 100
# Step 5417 Loss 1.0850526 Correct 42 out of 100
# Step 5418 Loss 1.092842 Correct 38 out of 100
# Step 5419 Loss 1.094727 Correct 37 out of 100
# Step 5420 Loss 1.078887 Correct 45 out of 100
# Step 5421 Loss 1.0891724 Correct 40 out of 100
# Step 5422 Loss 1.0985992 Correct 35 out of 100
# Step 5423 Loss 1.1208072 Correct 24 out of 100
# Step 5424 Loss 1.0979886 Correct 35 out of 100
# Step 5425 Loss 1.0948586 Correct 37 out of 100
# Step 5426 Loss 1.094509 Correct 37 out of 100
# Step 5427 Loss 1.0838351 Correct 43 out of 100
# Step 5428 Loss 1.0977827 Correct 36 out of 100
# Step 5429 Loss 1.0972154 Correct 36 out of 100
# Step 5430 Loss 1.1016855 Correct 33 out of 100
# Step 5431 Loss 1.0889989 Correct 40 out of 100
# Step 5432 Loss 1.0956833 Correct 37 out of 100
# Step 5433 Loss 1.0894723 Correct 40 out of 100
# Step 5434 Loss 1.0888276 Correct 40 out of 100
# Step 5435 Loss 1.0832907 Correct 43 out of 100
# Step 5436 Loss 1.1010423 Correct 34 out of 100
# Step 5437 Loss 1.104174 Correct 32 out of 100
# Step 5438 Loss 1.096826 Correct 36 out of 100
# Step 5439 Loss 1.0821756 Correct 44 out of 100
# Step 5440 Loss 1.0965596 Correct 36 out of 100
# Step 5441 Loss 1.096679 Correct 36 out of 100
# Step 5442 Loss 1.0859809 Correct 42 out of 100
# Step 5443 Loss 1.0879558 Correct 41 out of 100
# Step 5444 Loss 1.0810269 Correct 44 out of 100
# Step 5445 Loss 1.0902478 Correct 39 out of 100
# Step 5446 Loss 1.0851976 Correct 42 out of 100
# Step 5447 Loss 1.1024584 Correct 33 out of 100
# Step 5448 Loss 1.1042771 Correct 32 out of 100
# Step 5449 Loss 1.0819632 Correct 44 out of 100
# Step 5450 Loss 1.0965697 Correct 36 out of 100
# Step 5451 Loss 1.1082823 Correct 30 out of 100
# Step 5452 Loss 1.0754825 Correct 47 out of 100
# Step 5453 Loss 1.1002457 Correct 34 out of 100
# Step 5454 Loss 1.080815 Correct 44 out of 100
# Step 5455 Loss 1.0867224 Correct 41 out of 100
# Step 5456 Loss 1.0985234 Correct 35 out of 100
# Step 5457 Loss 1.0869938 Correct 41 out of 100
# Step 5458 Loss 1.0922364 Correct 38 out of 100
# Step 5459 Loss 1.1066343 Correct 31 out of 100
# Step 5460 Loss 1.0968964 Correct 36 out of 100
# Step 5461 Loss 1.0811177 Correct 44 out of 100
# Step 5462 Loss 1.0983301 Correct 35 out of 100
# Step 5463 Loss 1.0790524 Correct 45 out of 100
# Step 5464 Loss 1.0962443 Correct 36 out of 100
# Step 5465 Loss 1.1060703 Correct 31 out of 100
# Step 5466 Loss 1.0991057 Correct 35 out of 100
# Step 5467 Loss 1.1003255 Correct 34 out of 100
# Step 5468 Loss 1.0890212 Correct 40 out of 100
# Step 5469 Loss 1.0968515 Correct 36 out of 100
# Step 5470 Loss 1.0773067 Correct 46 out of 100
# Step 5471 Loss 1.0931078 Correct 38 out of 100
# Step 5472 Loss 1.0987849 Correct 35 out of 100
# Step 5473 Loss 1.0991585 Correct 35 out of 100
# Step 5474 Loss 1.1096641 Correct 29 out of 100
# Step 5475 Loss 1.0876839 Correct 41 out of 100
# Step 5476 Loss 1.0828562 Correct 43 out of 100
# Step 5477 Loss 1.0811597 Correct 44 out of 100
# Step 5478 Loss 1.0941621 Correct 37 out of 100
# Step 5479 Loss 1.0750881 Correct 47 out of 100
# Step 5480 Loss 1.0989921 Correct 35 out of 100
# Step 5481 Loss 1.1138972 Correct 27 out of 100
# Step 5482 Loss 1.0938073 Correct 37 out of 100
# Step 5483 Loss 1.0855196 Correct 41 out of 100
# Step 5484 Loss 1.0859886 Correct 41 out of 100
# Step 5485 Loss 1.1005529 Correct 34 out of 100
# Step 5486 Loss 1.0813231 Correct 44 out of 100
# Step 5487 Loss 1.0923533 Correct 38 out of 100
# Step 5488 Loss 1.1074144 Correct 30 out of 100
# Step 5489 Loss 1.0843861 Correct 42 out of 100
# Step 5490 Loss 1.1031467 Correct 33 out of 100
# Step 5491 Loss 1.0918425 Correct 38 out of 100
# Step 5492 Loss 1.0782089 Correct 45 out of 100
# Step 5493 Loss 1.0880948 Correct 41 out of 100
# Step 5494 Loss 1.1149526 Correct 27 out of 100
# Step 5495 Loss 1.0827761 Correct 43 out of 100
# Step 5496 Loss 1.0636064 Correct 53 out of 100
# Step 5497 Loss 1.1054232 Correct 32 out of 100
# Step 5498 Loss 1.0851223 Correct 42 out of 100
# Step 5499 Loss 1.1137718 Correct 27 out of 100
# Step 5500 Loss 1.1010627 Correct 34 out of 100
# Step 5501 Loss 1.1019223 Correct 33 out of 100
# Step 5502 Loss 1.1017556 Correct 33 out of 100
# Step 5503 Loss 1.0908228 Correct 39 out of 100
# Step 5504 Loss 1.0838878 Correct 42 out of 100
# Step 5505 Loss 1.0863305 Correct 41 out of 100
# Step 5506 Loss 1.0893428 Correct 39 out of 100
# Step 5507 Loss 1.111726 Correct 28 out of 100
# Step 5508 Loss 1.0986944 Correct 34 out of 100
# Step 5509 Loss 1.0874507 Correct 40 out of 100
# Step 5510 Loss 1.0860006 Correct 41 out of 100
# Step 5511 Loss 1.0774125 Correct 46 out of 100
# Step 5512 Loss 1.0831636 Correct 42 out of 100
# Step 5513 Loss 1.1006542 Correct 34 out of 100
# Step 5514 Loss 1.099018 Correct 35 out of 100
# Step 5515 Loss 1.1102971 Correct 29 out of 100
# Step 5516 Loss 1.0932691 Correct 38 out of 100
# Step 5517 Loss 1.0811548 Correct 43 out of 100
# Step 5518 Loss 1.0909259 Correct 38 out of 100
# Step 5519 Loss 1.0866925 Correct 41 out of 100
# Step 5520 Loss 1.0920635 Correct 38 out of 100
# Step 5521 Loss 1.1116065 Correct 29 out of 100
# Step 5522 Loss 1.0977541 Correct 35 out of 100
# Step 5523 Loss 1.0898845 Correct 38 out of 100
# Step 5524 Loss 1.0882555 Correct 39 out of 100
# Step 5525 Loss 1.0865636 Correct 40 out of 100
# Step 5526 Loss 1.0872113 Correct 41 out of 100
# Step 5527 Loss 1.0970201 Correct 36 out of 100
# Step 5528 Loss 1.0924627 Correct 38 out of 100
# Step 5529 Loss 1.0865608 Correct 41 out of 100
# Step 5530 Loss 1.0878279 Correct 41 out of 100
# Step 5531 Loss 1.1048827 Correct 31 out of 100
# Step 5532 Loss 1.1048294 Correct 32 out of 100
# Step 5533 Loss 1.1005168 Correct 34 out of 100
# Step 5534 Loss 1.0857491 Correct 41 out of 100
# Step 5535 Loss 1.0991805 Correct 34 out of 100
# Step 5536 Loss 1.1001724 Correct 33 out of 100
# Step 5537 Loss 1.1140808 Correct 29 out of 100
# Step 5538 Loss 1.1006925 Correct 34 out of 100
# Step 5539 Loss 1.0847921 Correct 43 out of 100
# Step 5540 Loss 1.1036352 Correct 32 out of 100
# Step 5541 Loss 1.0908922 Correct 40 out of 100
# Step 5542 Loss 1.1129249 Correct 27 out of 100
# Step 5543 Loss 1.1036042 Correct 33 out of 100
# Step 5544 Loss 1.0889277 Correct 40 out of 100
# Step 5545 Loss 1.094791 Correct 37 out of 100
# Step 5546 Loss 1.1016018 Correct 33 out of 100
# Step 5547 Loss 1.0839686 Correct 42 out of 100
# Step 5548 Loss 1.1007789 Correct 33 out of 100
# Step 5549 Loss 1.0968344 Correct 36 out of 100
# Step 5550 Loss 1.0988367 Correct 34 out of 100
# Step 5551 Loss 1.1033678 Correct 32 out of 100
# Step 5552 Loss 1.0954798 Correct 37 out of 100
# Step 5553 Loss 1.0949445 Correct 37 out of 100
# Step 5554 Loss 1.0920541 Correct 40 out of 100
# Step 5555 Loss 1.1060578 Correct 31 out of 100
# Step 5556 Loss 1.1099675 Correct 28 out of 100
# Step 5557 Loss 1.0970148 Correct 35 out of 100
# Step 5558 Loss 1.0903324 Correct 40 out of 100
# Step 5559 Loss 1.1119449 Correct 26 out of 100
# Step 5560 Loss 1.10854 Correct 29 out of 100
# Step 5561 Loss 1.0961403 Correct 35 out of 100
# Step 5562 Loss 1.0952594 Correct 36 out of 100
# Step 5563 Loss 1.0990528 Correct 33 out of 100
# Step 5564 Loss 1.0988678 Correct 35 out of 100
# Step 5565 Loss 1.0797592 Correct 47 out of 100
# Step 5566 Loss 1.1091666 Correct 28 out of 100
# Step 5567 Loss 1.102218 Correct 33 out of 100
# Step 5568 Loss 1.0869042 Correct 41 out of 100
# Step 5569 Loss 1.0971731 Correct 35 out of 100
# Step 5570 Loss 1.0980635 Correct 35 out of 100
# Step 5571 Loss 1.0931915 Correct 37 out of 100
# Step 5572 Loss 1.09098 Correct 39 out of 100
# Step 5573 Loss 1.0911021 Correct 37 out of 100
# Step 5574 Loss 1.0888187 Correct 41 out of 100
# Step 5575 Loss 1.0915403 Correct 38 out of 100
# Step 5576 Loss 1.0993093 Correct 35 out of 100
# Step 5577 Loss 1.0860686 Correct 42 out of 100
# Step 5578 Loss 1.0820619 Correct 44 out of 100
# Step 5579 Loss 1.092485 Correct 40 out of 100
# Step 5580 Loss 1.1026033 Correct 32 out of 100
# Step 5581 Loss 1.0859303 Correct 41 out of 100
# Step 5582 Loss 1.0991055 Correct 33 out of 100
# Step 5583 Loss 1.1010247 Correct 33 out of 100
# Step 5584 Loss 1.108225 Correct 28 out of 100
# Step 5585 Loss 1.0856763 Correct 43 out of 100
# Step 5586 Loss 1.0983716 Correct 35 out of 100
# Step 5587 Loss 1.0916624 Correct 38 out of 100
# Step 5588 Loss 1.081596 Correct 44 out of 100
# Step 5589 Loss 1.1018693 Correct 34 out of 100
# Step 5590 Loss 1.1013713 Correct 33 out of 100
# Step 5591 Loss 1.0851831 Correct 43 out of 100
# Step 5592 Loss 1.0932214 Correct 37 out of 100
# Step 5593 Loss 1.1105171 Correct 29 out of 100
# Step 5594 Loss 1.0865965 Correct 42 out of 100
# Step 5595 Loss 1.1001842 Correct 33 out of 100
# Step 5596 Loss 1.0852433 Correct 43 out of 100
# Step 5597 Loss 1.0995891 Correct 33 out of 100
# Step 5598 Loss 1.0975935 Correct 35 out of 100
# Step 5599 Loss 1.0924482 Correct 40 out of 100
# Step 5600 Loss 1.0932748 Correct 37 out of 100
# Step 5601 Loss 1.0866488 Correct 42 out of 100
# Step 5602 Loss 1.0960284 Correct 36 out of 100
# Step 5603 Loss 1.1038342 Correct 31 out of 100
# Step 5604 Loss 1.089346 Correct 39 out of 100
# Step 5605 Loss 1.1029804 Correct 32 out of 100
# Step 5606 Loss 1.092418 Correct 38 out of 100
# Step 5607 Loss 1.0993998 Correct 33 out of 100
# Step 5608 Loss 1.0983078 Correct 35 out of 100
# Step 5609 Loss 1.0915074 Correct 39 out of 100
# Step 5610 Loss 1.0932173 Correct 38 out of 100
# Step 5611 Loss 1.0953877 Correct 36 out of 100
# Step 5612 Loss 1.0989891 Correct 34 out of 100
# Step 5613 Loss 1.0922673 Correct 38 out of 100
# Step 5614 Loss 1.0973417 Correct 34 out of 100
# Step 5615 Loss 1.0963359 Correct 36 out of 100
# Step 5616 Loss 1.0952989 Correct 37 out of 100
# Step 5617 Loss 1.1020013 Correct 32 out of 100
# Step 5618 Loss 1.1009942 Correct 33 out of 100
# Step 5619 Loss 1.1069216 Correct 28 out of 100
# Step 5620 Loss 1.089069 Correct 41 out of 100
# Step 5621 Loss 1.0999106 Correct 34 out of 100
# Step 5622 Loss 1.0958526 Correct 35 out of 100
# Step 5623 Loss 1.0819424 Correct 47 out of 100
# Step 5624 Loss 1.0994989 Correct 33 out of 100
# Step 5625 Loss 1.1000588 Correct 34 out of 100
# Step 5626 Loss 1.0958226 Correct 36 out of 100
# Step 5627 Loss 1.0990863 Correct 33 out of 100
# Step 5628 Loss 1.0936444 Correct 37 out of 100
# Step 5629 Loss 1.0880628 Correct 41 out of 100
# Step 5630 Loss 1.0985438 Correct 35 out of 100
# Step 5631 Loss 1.1021852 Correct 33 out of 100
# Step 5632 Loss 1.0862867 Correct 42 out of 100
# Step 5633 Loss 1.0797448 Correct 47 out of 100
# Step 5634 Loss 1.1019585 Correct 32 out of 100
# Step 5635 Loss 1.0937535 Correct 38 out of 100
# Step 5636 Loss 1.1039497 Correct 32 out of 100
# Step 5637 Loss 1.0857193 Correct 43 out of 100
# Step 5638 Loss 1.088945 Correct 40 out of 100
# Step 5639 Loss 1.0830102 Correct 44 out of 100
# Step 5640 Loss 1.1090767 Correct 27 out of 100
# Step 5641 Loss 1.085241 Correct 43 out of 100
# Step 5642 Loss 1.1000828 Correct 34 out of 100
# Step 5643 Loss 1.0872458 Correct 42 out of 100
# Step 5644 Loss 1.0865893 Correct 41 out of 100
# Step 5645 Loss 1.0937845 Correct 37 out of 100
# Step 5646 Loss 1.0960627 Correct 36 out of 100
# Step 5647 Loss 1.1023647 Correct 33 out of 100
# Step 5648 Loss 1.0904745 Correct 39 out of 100
# Step 5649 Loss 1.0881393 Correct 42 out of 100
# Step 5650 Loss 1.0917978 Correct 38 out of 100
# Step 5651 Loss 1.097462 Correct 34 out of 100
# Step 5652 Loss 1.1025777 Correct 32 out of 100
# Step 5653 Loss 1.0877104 Correct 41 out of 100
# Step 5654 Loss 1.0815158 Correct 45 out of 100
# Step 5655 Loss 1.0899689 Correct 40 out of 100
# Step 5656 Loss 1.1119945 Correct 27 out of 100
# Step 5657 Loss 1.0997123 Correct 34 out of 100
# Step 5658 Loss 1.102277 Correct 32 out of 100
# Step 5659 Loss 1.1078327 Correct 28 out of 100
# Step 5660 Loss 1.0812874 Correct 46 out of 100
# Step 5661 Loss 1.0941542 Correct 36 out of 100
# Step 5662 Loss 1.0978827 Correct 35 out of 100
# Step 5663 Loss 1.1054101 Correct 30 out of 100
# Step 5664 Loss 1.0944577 Correct 36 out of 100
# Step 5665 Loss 1.1042597 Correct 30 out of 100
# Step 5666 Loss 1.1041423 Correct 30 out of 100
# Step 5667 Loss 1.0980814 Correct 34 out of 100
# Step 5668 Loss 1.0915238 Correct 40 out of 100
# Step 5669 Loss 1.0968167 Correct 35 out of 100
# Step 5670 Loss 1.0938056 Correct 37 out of 100
# Step 5671 Loss 1.0913674 Correct 38 out of 100
# Step 5672 Loss 1.0943912 Correct 37 out of 100
# Step 5673 Loss 1.0936447 Correct 36 out of 100
# Step 5674 Loss 1.0948902 Correct 36 out of 100
# Step 5675 Loss 1.1071731 Correct 28 out of 100
# Step 5676 Loss 1.0985287 Correct 34 out of 100
# Step 5677 Loss 1.1073642 Correct 29 out of 100
# Step 5678 Loss 1.0976293 Correct 36 out of 100
# Step 5679 Loss 1.0862559 Correct 43 out of 100
# Step 5680 Loss 1.1011803 Correct 32 out of 100
# Step 5681 Loss 1.0926207 Correct 39 out of 100
# Step 5682 Loss 1.0992501 Correct 33 out of 100
# Step 5683 Loss 1.0888281 Correct 40 out of 100
# Step 5684 Loss 1.0869082 Correct 42 out of 100
# Step 5685 Loss 1.0988622 Correct 35 out of 100
# Step 5686 Loss 1.0944932 Correct 37 out of 100
# Step 5687 Loss 1.0967796 Correct 35 out of 100
# Step 5688 Loss 1.0910393 Correct 39 out of 100
# Step 5689 Loss 1.0790199 Correct 48 out of 100
# Step 5690 Loss 1.0994124 Correct 34 out of 100
# Step 5691 Loss 1.0996455 Correct 32 out of 100
# Step 5692 Loss 1.0882684 Correct 41 out of 100
# Step 5693 Loss 1.0982716 Correct 35 out of 100
# Step 5694 Loss 1.0833192 Correct 45 out of 100
# Step 5695 Loss 1.1028948 Correct 31 out of 100
# Step 5696 Loss 1.0951109 Correct 37 out of 100
# Step 5697 Loss 1.0950502 Correct 38 out of 100
# Step 5698 Loss 1.0910106 Correct 39 out of 100
# Step 5699 Loss 1.1078908 Correct 28 out of 100
# Step 5700 Loss 1.1029651 Correct 30 out of 100
# Step 5701 Loss 1.0962358 Correct 35 out of 100
# Step 5702 Loss 1.0890142 Correct 42 out of 100
# Step 5703 Loss 1.0959916 Correct 37 out of 100
# Step 5704 Loss 1.091799 Correct 39 out of 100
# Step 5705 Loss 1.1021312 Correct 31 out of 100
# Step 5706 Loss 1.0984256 Correct 34 out of 100
# Step 5707 Loss 1.0863979 Correct 42 out of 100
# Step 5708 Loss 1.0857158 Correct 43 out of 100
# Step 5709 Loss 1.0912988 Correct 39 out of 100
# Step 5710 Loss 1.092369 Correct 38 out of 100
# Step 5711 Loss 1.0960425 Correct 36 out of 100
# Step 5712 Loss 1.0890976 Correct 40 out of 100
# Step 5713 Loss 1.0958554 Correct 36 out of 100
# Step 5714 Loss 1.0847684 Correct 42 out of 100
# Step 5715 Loss 1.0995669 Correct 33 out of 100
# Step 5716 Loss 1.1004485 Correct 33 out of 100
# Step 5717 Loss 1.0893652 Correct 40 out of 100
# Step 5718 Loss 1.0853952 Correct 43 out of 100
# Step 5719 Loss 1.085179 Correct 42 out of 100
# Step 5720 Loss 1.0963273 Correct 36 out of 100
# Step 5721 Loss 1.1002384 Correct 33 out of 100
# Step 5722 Loss 1.0938168 Correct 37 out of 100
# Step 5723 Loss 1.0992997 Correct 34 out of 100
# Step 5724 Loss 1.0983846 Correct 35 out of 100
# Step 5725 Loss 1.0884182 Correct 41 out of 100
# Step 5726 Loss 1.0832449 Correct 44 out of 100
# Step 5727 Loss 1.1055812 Correct 30 out of 100
# Step 5728 Loss 1.0967193 Correct 36 out of 100
# Step 5729 Loss 1.089807 Correct 40 out of 100
# Step 5730 Loss 1.0942799 Correct 37 out of 100
# Step 5731 Loss 1.098639 Correct 34 out of 100
# Step 5732 Loss 1.1004622 Correct 34 out of 100
# Step 5733 Loss 1.0937918 Correct 37 out of 100
# Step 5734 Loss 1.0840721 Correct 44 out of 100
# Step 5735 Loss 1.080618 Correct 45 out of 100
# Step 5736 Loss 1.0993263 Correct 34 out of 100
# Step 5737 Loss 1.0951978 Correct 36 out of 100
# Step 5738 Loss 1.1000675 Correct 34 out of 100
# Step 5739 Loss 1.1031822 Correct 31 out of 100
# Step 5740 Loss 1.0908307 Correct 39 out of 100
# Step 5741 Loss 1.0868757 Correct 42 out of 100
# Step 5742 Loss 1.0995365 Correct 33 out of 100
# Step 5743 Loss 1.0894139 Correct 41 out of 100
# Step 5744 Loss 1.0967058 Correct 35 out of 100
# Step 5745 Loss 1.0800099 Correct 46 out of 100
# Step 5746 Loss 1.0849897 Correct 43 out of 100
# Step 5747 Loss 1.086772 Correct 42 out of 100
# Step 5748 Loss 1.1049776 Correct 31 out of 100
# Step 5749 Loss 1.0991544 Correct 34 out of 100
# Step 5750 Loss 1.0974967 Correct 35 out of 100
# Step 5751 Loss 1.1019454 Correct 32 out of 100
# Step 5752 Loss 1.0812731 Correct 45 out of 100
# Step 5753 Loss 1.0941093 Correct 37 out of 100
# Step 5754 Loss 1.0989236 Correct 34 out of 100
# Step 5755 Loss 1.1024474 Correct 32 out of 100
# Step 5756 Loss 1.0988764 Correct 34 out of 100
# Step 5757 Loss 1.1098977 Correct 27 out of 100
# Step 5758 Loss 1.1127871 Correct 25 out of 100
# Step 5759 Loss 1.0795621 Correct 47 out of 100
# Step 5760 Loss 1.091219 Correct 39 out of 100
# Step 5761 Loss 1.0933895 Correct 38 out of 100
# Step 5762 Loss 1.0954759 Correct 36 out of 100
# Step 5763 Loss 1.0959607 Correct 36 out of 100
# Step 5764 Loss 1.0834646 Correct 44 out of 100
# Step 5765 Loss 1.0927494 Correct 38 out of 100
# Step 5766 Loss 1.1006324 Correct 33 out of 100
# Step 5767 Loss 1.0862046 Correct 42 out of 100
# Step 5768 Loss 1.0864167 Correct 42 out of 100
# Step 5769 Loss 1.0971465 Correct 35 out of 100
# Step 5770 Loss 1.0887746 Correct 40 out of 100
# Step 5771 Loss 1.0979801 Correct 34 out of 100
# Step 5772 Loss 1.0951568 Correct 37 out of 100
# Step 5773 Loss 1.0785017 Correct 47 out of 100
# Step 5774 Loss 1.100363 Correct 33 out of 100
# Step 5775 Loss 1.0846691 Correct 43 out of 100
# Step 5776 Loss 1.1005818 Correct 33 out of 100
# Step 5777 Loss 1.0918952 Correct 38 out of 100
# Step 5778 Loss 1.1032578 Correct 31 out of 100
# Step 5779 Loss 1.0978655 Correct 35 out of 100
# Step 5780 Loss 1.0858494 Correct 42 out of 100
# Step 5781 Loss 1.100867 Correct 33 out of 100
# Step 5782 Loss 1.1041095 Correct 31 out of 100
# Step 5783 Loss 1.0887145 Correct 40 out of 100
# Step 5784 Loss 1.0890056 Correct 40 out of 100
# Step 5785 Loss 1.085487 Correct 42 out of 100
# Step 5786 Loss 1.0922326 Correct 38 out of 100
# Step 5787 Loss 1.0890768 Correct 40 out of 100
# Step 5788 Loss 1.1087383 Correct 28 out of 100
# Step 5789 Loss 1.0833542 Correct 44 out of 100
# Step 5790 Loss 1.095693 Correct 36 out of 100
# Step 5791 Loss 1.1052037 Correct 30 out of 100
# Step 5792 Loss 1.0972524 Correct 35 out of 100
# Step 5793 Loss 1.1007814 Correct 33 out of 100
# Step 5794 Loss 1.1033118 Correct 31 out of 100
# Step 5795 Loss 1.0910134 Correct 39 out of 100
# Step 5796 Loss 1.0958829 Correct 36 out of 100
# Step 5797 Loss 1.1066475 Correct 29 out of 100
# Step 5798 Loss 1.1000705 Correct 33 out of 100
# Step 5799 Loss 1.101662 Correct 32 out of 100
# Step 5800 Loss 1.0940561 Correct 37 out of 100
# Step 5801 Loss 1.0908853 Correct 39 out of 100
# Step 5802 Loss 1.0963229 Correct 35 out of 100
# Step 5803 Loss 1.1131785 Correct 25 out of 100
# Step 5804 Loss 1.078066 Correct 48 out of 100
# Step 5805 Loss 1.1073556 Correct 28 out of 100
# Step 5806 Loss 1.100613 Correct 32 out of 100
# Step 5807 Loss 1.1054441 Correct 29 out of 100
# Step 5808 Loss 1.0972284 Correct 35 out of 100
# Step 5809 Loss 1.1185287 Correct 20 out of 100
# Step 5810 Loss 1.1049734 Correct 29 out of 100
# Step 5811 Loss 1.0900537 Correct 40 out of 100
# Step 5812 Loss 1.0860039 Correct 43 out of 100
# Step 5813 Loss 1.0943358 Correct 37 out of 100
# Step 5814 Loss 1.096592 Correct 35 out of 100
# Step 5815 Loss 1.0988562 Correct 33 out of 100
# Step 5816 Loss 1.0898044 Correct 40 out of 100
# Step 5817 Loss 1.0875245 Correct 42 out of 100
# Step 5818 Loss 1.0922989 Correct 38 out of 100
# Step 5819 Loss 1.0936784 Correct 37 out of 100
# Step 5820 Loss 1.0910666 Correct 39 out of 100
# Step 5821 Loss 1.0957869 Correct 36 out of 100
# Step 5822 Loss 1.0874218 Correct 42 out of 100
# Step 5823 Loss 1.0973703 Correct 35 out of 100
# Step 5824 Loss 1.0852104 Correct 43 out of 100
# Step 5825 Loss 1.092033 Correct 38 out of 100
# Step 5826 Loss 1.0960393 Correct 35 out of 100
# Step 5827 Loss 1.102224 Correct 31 out of 100
# Step 5828 Loss 1.09669 Correct 35 out of 100
# Step 5829 Loss 1.0966142 Correct 35 out of 100
# Step 5830 Loss 1.109798 Correct 26 out of 100
# Step 5831 Loss 1.0782523 Correct 48 out of 100
# Step 5832 Loss 1.1012443 Correct 32 out of 100
# Step 5833 Loss 1.1026231 Correct 31 out of 100
# Step 5834 Loss 1.0875542 Correct 41 out of 100
# Step 5835 Loss 1.0973355 Correct 34 out of 100
# Step 5836 Loss 1.0880952 Correct 41 out of 100
# Step 5837 Loss 1.0813016 Correct 46 out of 100
# Step 5838 Loss 1.0863867 Correct 42 out of 100
# Step 5839 Loss 1.102877 Correct 31 out of 100
# Step 5840 Loss 1.0916504 Correct 39 out of 100
# Step 5841 Loss 1.0941771 Correct 37 out of 100
# Step 5842 Loss 1.0924647 Correct 38 out of 100
# Step 5843 Loss 1.0899125 Correct 40 out of 100
# Step 5844 Loss 1.095596 Correct 36 out of 100
# Step 5845 Loss 1.0906864 Correct 39 out of 100
# Step 5846 Loss 1.0832791 Correct 44 out of 100
# Step 5847 Loss 1.0984802 Correct 34 out of 100
# Step 5848 Loss 1.1041807 Correct 30 out of 100
# Step 5849 Loss 1.0869228 Correct 42 out of 100
# Step 5850 Loss 1.0936528 Correct 37 out of 100
# Step 5851 Loss 1.0855669 Correct 42 out of 100
# Step 5852 Loss 1.0996389 Correct 33 out of 100
# Step 5853 Loss 1.0957439 Correct 36 out of 100
# Step 5854 Loss 1.0866637 Correct 42 out of 100
# Step 5855 Loss 1.1013714 Correct 32 out of 100
# Step 5856 Loss 1.1037425 Correct 31 out of 100
# Step 5857 Loss 1.0970769 Correct 35 out of 100
# Step 5858 Loss 1.0980732 Correct 34 out of 100
# Step 5859 Loss 1.1070813 Correct 28 out of 100
# Step 5860 Loss 1.0991379 Correct 33 out of 100
# Step 5861 Loss 1.0928128 Correct 38 out of 100
# Step 5862 Loss 1.0885403 Correct 41 out of 100
# Step 5863 Loss 1.0933133 Correct 37 out of 100
# Step 5864 Loss 1.101384 Correct 32 out of 100
# Step 5865 Loss 1.0915405 Correct 39 out of 100
# Step 5866 Loss 1.0905193 Correct 39 out of 100
# Step 5867 Loss 1.1112037 Correct 25 out of 100
# Step 5868 Loss 1.0851363 Correct 43 out of 100
# Step 5869 Loss 1.1013893 Correct 32 out of 100
# Step 5870 Loss 1.0992513 Correct 33 out of 100
# Step 5871 Loss 1.1009504 Correct 32 out of 100
# Step 5872 Loss 1.0923247 Correct 38 out of 100
# Step 5873 Loss 1.0963746 Correct 35 out of 100
# Step 5874 Loss 1.0779681 Correct 48 out of 100
# Step 5875 Loss 1.0843979 Correct 44 out of 100
# Step 5876 Loss 1.1042703 Correct 30 out of 100
# Step 5877 Loss 1.0912354 Correct 38 out of 100
# Step 5878 Loss 1.0938945 Correct 37 out of 100
# Step 5879 Loss 1.0945469 Correct 37 out of 100
# Step 5880 Loss 1.0927539 Correct 38 out of 100
# Step 5881 Loss 1.1063414 Correct 28 out of 100
# Step 5882 Loss 1.0858781 Correct 42 out of 100
# Step 5883 Loss 1.096709 Correct 35 out of 100
# Step 5884 Loss 1.0964494 Correct 35 out of 100
# Step 5885 Loss 1.0895504 Correct 40 out of 100
# Step 5886 Loss 1.0896193 Correct 40 out of 100
# Step 5887 Loss 1.0834359 Correct 44 out of 100
# Step 5888 Loss 1.0916668 Correct 38 out of 100
# Step 5889 Loss 1.1025473 Correct 31 out of 100
# Step 5890 Loss 1.1034735 Correct 30 out of 100
# Step 5891 Loss 1.095296 Correct 36 out of 100
# Step 5892 Loss 1.1031383 Correct 30 out of 100
# Step 5893 Loss 1.075501 Correct 50 out of 100
# Step 5894 Loss 1.0834414 Correct 44 out of 100
# Step 5895 Loss 1.0936761 Correct 37 out of 100
# Step 5896 Loss 1.1026206 Correct 31 out of 100
# Step 5897 Loss 1.0920596 Correct 38 out of 100
# Step 5898 Loss 1.0987232 Correct 34 out of 100
# Step 5899 Loss 1.0905489 Correct 39 out of 100
# Step 5900 Loss 1.0965849 Correct 35 out of 100
# Step 5901 Loss 1.0898155 Correct 39 out of 100
# Step 5902 Loss 1.0831321 Correct 44 out of 100
# Step 5903 Loss 1.1030226 Correct 31 out of 100
# Step 5904 Loss 1.0896702 Correct 39 out of 100
# Step 5905 Loss 1.0858537 Correct 42 out of 100
# Step 5906 Loss 1.0919145 Correct 38 out of 100
# Step 5907 Loss 1.0801841 Correct 46 out of 100
# Step 5908 Loss 1.1011661 Correct 33 out of 100
# Step 5909 Loss 1.0919987 Correct 38 out of 100
# Step 5910 Loss 1.079741 Correct 45 out of 100
# Step 5911 Loss 1.0934178 Correct 37 out of 100
# Step 5912 Loss 1.1017201 Correct 32 out of 100
# Step 5913 Loss 1.0896741 Correct 40 out of 100
# Step 5914 Loss 1.0923665 Correct 38 out of 100
# Step 5915 Loss 1.0992925 Correct 33 out of 100
# Step 5916 Loss 1.1068913 Correct 29 out of 100
# Step 5917 Loss 1.0964226 Correct 35 out of 100
# Step 5918 Loss 1.0963343 Correct 35 out of 100
# Step 5919 Loss 1.1027117 Correct 31 out of 100
# Step 5920 Loss 1.090842 Correct 38 out of 100
# Step 5921 Loss 1.0971012 Correct 35 out of 100
# Step 5922 Loss 1.0875841 Correct 41 out of 100
# Step 5923 Loss 1.1015003 Correct 32 out of 100
# Step 5924 Loss 1.0919833 Correct 38 out of 100
# Step 5925 Loss 1.0871193 Correct 41 out of 100
# Step 5926 Loss 1.0980419 Correct 35 out of 100
# Step 5927 Loss 1.0853513 Correct 42 out of 100
# Step 5928 Loss 1.0843767 Correct 43 out of 100
# Step 5929 Loss 1.1032256 Correct 31 out of 100
# Step 5930 Loss 1.097437 Correct 35 out of 100
# Step 5931 Loss 1.0796404 Correct 46 out of 100
# Step 5932 Loss 1.0919038 Correct 38 out of 100
# Step 5933 Loss 1.0887963 Correct 40 out of 100
# Step 5934 Loss 1.1012542 Correct 32 out of 100
# Step 5935 Loss 1.1061454 Correct 29 out of 100
# Step 5936 Loss 1.0871072 Correct 42 out of 100
# Step 5937 Loss 1.093443 Correct 37 out of 100
# Step 5938 Loss 1.0869178 Correct 41 out of 100
# Step 5939 Loss 1.0808547 Correct 45 out of 100
# Step 5940 Loss 1.092961 Correct 37 out of 100
# Step 5941 Loss 1.084464 Correct 42 out of 100
# Step 5942 Loss 1.0944425 Correct 36 out of 100
# Step 5943 Loss 1.0883609 Correct 40 out of 100
# Step 5944 Loss 1.0933537 Correct 37 out of 100
# Step 5945 Loss 1.0883355 Correct 39 out of 100
# Step 5946 Loss 1.0917143 Correct 38 out of 100
# Step 5947 Loss 1.1079727 Correct 28 out of 100
# Step 5948 Loss 1.0899937 Correct 39 out of 100
# Step 5949 Loss 1.0834049 Correct 44 out of 100
# Step 5950 Loss 1.0954894 Correct 36 out of 100
# Step 5951 Loss 1.1026566 Correct 32 out of 100
# Step 5952 Loss 1.0781436 Correct 46 out of 100
# Step 5953 Loss 1.1077313 Correct 28 out of 100
# Step 5954 Loss 1.1059877 Correct 29 out of 100
# Step 5955 Loss 1.0782284 Correct 46 out of 100
# Step 5956 Loss 1.1057585 Correct 30 out of 100
# Step 5957 Loss 1.083386 Correct 43 out of 100
# Step 5958 Loss 1.094907 Correct 36 out of 100
# Step 5959 Loss 1.0855298 Correct 42 out of 100
# Step 5960 Loss 1.092833 Correct 37 out of 100
# Step 5961 Loss 1.0944623 Correct 36 out of 100
# Step 5962 Loss 1.08599 Correct 42 out of 100
# Step 5963 Loss 1.1007669 Correct 33 out of 100
# Step 5964 Loss 1.1007471 Correct 33 out of 100
# Step 5965 Loss 1.0875063 Correct 40 out of 100
# Step 5966 Loss 1.0822549 Correct 44 out of 100
# Step 5967 Loss 1.0952957 Correct 36 out of 100
# Step 5968 Loss 1.0873437 Correct 41 out of 100
# Step 5969 Loss 1.1041349 Correct 31 out of 100
# Step 5970 Loss 1.0891434 Correct 40 out of 100
# Step 5971 Loss 1.0965289 Correct 35 out of 100
# Step 5972 Loss 1.0973321 Correct 35 out of 100
# Step 5973 Loss 1.1032535 Correct 31 out of 100
# Step 5974 Loss 1.085795 Correct 41 out of 100
# Step 5975 Loss 1.0859191 Correct 41 out of 100
# Step 5976 Loss 1.0957148 Correct 35 out of 100
# Step 5977 Loss 1.0966069 Correct 35 out of 100
# Step 5978 Loss 1.0842063 Correct 42 out of 100
# Step 5979 Loss 1.0895612 Correct 40 out of 100
# Step 5980 Loss 1.0880936 Correct 40 out of 100
# Step 5981 Loss 1.0815579 Correct 44 out of 100
# Step 5982 Loss 1.0790489 Correct 45 out of 100
# Step 5983 Loss 1.0932631 Correct 37 out of 100
# Step 5984 Loss 1.0811273 Correct 44 out of 100
# Step 5985 Loss 1.0792274 Correct 45 out of 100
# Step 5986 Loss 1.1038041 Correct 31 out of 100
# Step 5987 Loss 1.0991353 Correct 34 out of 100
# Step 5988 Loss 1.0900841 Correct 39 out of 100
# Step 5989 Loss 1.1031855 Correct 32 out of 100
# Step 5990 Loss 1.0764202 Correct 47 out of 100
# Step 5991 Loss 1.1011502 Correct 33 out of 100
# Step 5992 Loss 1.0938268 Correct 37 out of 100
# Step 5993 Loss 1.091978 Correct 38 out of 100
# Step 5994 Loss 1.0909371 Correct 38 out of 100
# Step 5995 Loss 1.0918361 Correct 38 out of 100
# Step 5996 Loss 1.096318 Correct 35 out of 100
# Step 5997 Loss 1.0984961 Correct 34 out of 100
# Step 5998 Loss 1.0937572 Correct 37 out of 100
# Step 5999 Loss 1.1069715 Correct 29 out of 100
# Step 6000 Loss 1.1118718 Correct 26 out of 100
# Step 6001 Loss 1.0985988 Correct 34 out of 100
# Step 6002 Loss 1.0917537 Correct 38 out of 100
# Step 6003 Loss 1.0877025 Correct 40 out of 100
# Step 6004 Loss 1.0950708 Correct 36 out of 100
# Step 6005 Loss 1.079645 Correct 45 out of 100
# Step 6006 Loss 1.0968425 Correct 35 out of 100
# Step 6007 Loss 1.0929374 Correct 37 out of 100
# Step 6008 Loss 1.098339 Correct 34 out of 100
# Step 6009 Loss 1.0798815 Correct 45 out of 100
# Step 6010 Loss 1.0942619 Correct 36 out of 100
# Step 6011 Loss 1.0932014 Correct 37 out of 100
# Step 6012 Loss 1.0895052 Correct 39 out of 100
# Step 6013 Loss 1.0931785 Correct 37 out of 100
# Step 6014 Loss 1.1018388 Correct 32 out of 100
# Step 6015 Loss 1.097746 Correct 34 out of 100
# Step 6016 Loss 1.0860503 Correct 41 out of 100
# Step 6017 Loss 1.0826256 Correct 43 out of 100
# Step 6018 Loss 1.0999945 Correct 33 out of 100
# Step 6019 Loss 1.1001606 Correct 32 out of 100
# Step 6020 Loss 1.0905172 Correct 39 out of 100
# Step 6021 Loss 1.0968778 Correct 35 out of 100
# ...
# Step 9663 Loss 0.8412271 Correct 61 out of 100
# Step 9664 Loss 0.9276114 Correct 50 out of 100
# Step 9665 Loss 0.91922873 Correct 53 out of 100
# Step 9666 Loss 0.95085853 Correct 51 out of 100
# Step 9667 Loss 0.9641726 Correct 51 out of 100
# Step 9668 Loss 0.9046509 Correct 50 out of 100
# Step 9669 Loss 0.8907428 Correct 57 out of 100
# Step 9670 Loss 0.9275835 Correct 54 out of 100
# Step 9671 Loss 0.8787233 Correct 56 out of 100
# Step 9672 Loss 0.91647804 Correct 51 out of 100
# Step 9673 Loss 0.9491556 Correct 54 out of 100
# Step 9674 Loss 0.8633916 Correct 56 out of 100
# Step 9675 Loss 0.9195869 Correct 48 out of 100
# Step 9676 Loss 0.90697724 Correct 52 out of 100
# Step 9677 Loss 0.85978323 Correct 59 out of 100
# Step 9678 Loss 0.8994219 Correct 53 out of 100
# Step 9679 Loss 0.9370344 Correct 48 out of 100
# Step 9680 Loss 0.8685227 Correct 56 out of 100
# Step 9681 Loss 0.88477933 Correct 52 out of 100
# Step 9682 Loss 1.0573983 Correct 44 out of 100
# Step 9683 Loss 0.94931555 Correct 50 out of 100
# Step 9684 Loss 0.87889457 Correct 56 out of 100
# Step 9685 Loss 0.85734946 Correct 60 out of 100
# Step 9686 Loss 0.8620707 Correct 58 out of 100
# Step 9687 Loss 0.9143423 Correct 55 out of 100
# Step 9688 Loss 0.9027562 Correct 50 out of 100
# Step 9689 Loss 0.9144521 Correct 52 out of 100
# Step 9690 Loss 0.8376264 Correct 62 out of 100
# Step 9691 Loss 0.8061902 Correct 61 out of 100
# Step 9692 Loss 0.9616043 Correct 52 out of 100
# Step 9693 Loss 0.85326433 Correct 59 out of 100
# Step 9694 Loss 0.84680784 Correct 60 out of 100
# Step 9695 Loss 0.96586955 Correct 49 out of 100
# Step 9696 Loss 0.84545064 Correct 57 out of 100
# Step 9697 Loss 0.83858323 Correct 54 out of 100
# Step 9698 Loss 0.9437743 Correct 50 out of 100
# Step 9699 Loss 0.88450617 Correct 61 out of 100
# Step 9700 Loss 0.94044256 Correct 47 out of 100
# Step 9701 Loss 0.88223433 Correct 55 out of 100
# Step 9702 Loss 0.919191 Correct 48 out of 100
# Step 9703 Loss 0.8600865 Correct 58 out of 100
# Step 9704 Loss 0.9020381 Correct 50 out of 100
# Step 9705 Loss 0.87513906 Correct 53 out of 100
# Step 9706 Loss 0.8838052 Correct 45 out of 100
# Step 9707 Loss 0.8083752 Correct 56 out of 100
# Step 9708 Loss 0.8215019 Correct 55 out of 100
# Step 9709 Loss 1.0608912 Correct 47 out of 100
# Step 9710 Loss 1.0241227 Correct 52 out of 100
# Step 9711 Loss 0.9178128 Correct 53 out of 100
# Step 9712 Loss 0.9088435 Correct 53 out of 100
# Step 9713 Loss 0.91009414 Correct 49 out of 100
# Step 9714 Loss 0.9234234 Correct 57 out of 100
# Step 9715 Loss 0.8433205 Correct 60 out of 100
# Step 9716 Loss 0.88775545 Correct 48 out of 100
# Step 9717 Loss 0.90225846 Correct 54 out of 100
# Step 9718 Loss 0.86902326 Correct 55 out of 100
# Step 9719 Loss 0.9138693 Correct 56 out of 100
# Step 9720 Loss 0.9838011 Correct 58 out of 100
# Step 9721 Loss 0.8612477 Correct 56 out of 100
# Step 9722 Loss 0.9037857 Correct 52 out of 100
# Step 9723 Loss 0.83239627 Correct 64 out of 100
# Step 9724 Loss 0.9434941 Correct 56 out of 100
# Step 9725 Loss 0.8176972 Correct 60 out of 100
# Step 9726 Loss 0.9013178 Correct 51 out of 100
# Step 9727 Loss 1.0022981 Correct 45 out of 100
# Step 9728 Loss 0.93343514 Correct 51 out of 100
# Step 9729 Loss 0.8322797 Correct 56 out of 100
# Step 9730 Loss 0.9087066 Correct 48 out of 100
# Step 9731 Loss 0.8928244 Correct 53 out of 100
# Step 9732 Loss 0.90498835 Correct 53 out of 100
# Step 9733 Loss 0.9216764 Correct 53 out of 100
# Step 9734 Loss 0.89416957 Correct 56 out of 100
# Step 9735 Loss 0.90183675 Correct 52 out of 100
# Step 9736 Loss 0.93034583 Correct 54 out of 100
# Step 9737 Loss 0.881351 Correct 59 out of 100
# Step 9738 Loss 0.87875795 Correct 54 out of 100
# Step 9739 Loss 0.9618963 Correct 49 out of 100
# Step 9740 Loss 0.8578559 Correct 57 out of 100
# Step 9741 Loss 0.9335749 Correct 43 out of 100
# Step 9742 Loss 0.8670515 Correct 60 out of 100
# Step 9743 Loss 0.9186666 Correct 47 out of 100
# Step 9744 Loss 0.91620964 Correct 57 out of 100
# Step 9745 Loss 0.86670905 Correct 52 out of 100
# Step 9746 Loss 0.9429082 Correct 52 out of 100
# Step 9747 Loss 0.92896616 Correct 58 out of 100
# Step 9748 Loss 0.956642 Correct 50 out of 100
# Step 9749 Loss 0.85903704 Correct 54 out of 100
# Step 9750 Loss 0.87746066 Correct 58 out of 100
# Step 9751 Loss 0.871577 Correct 59 out of 100
# Step 9752 Loss 1.0064741 Correct 45 out of 100
# Step 9753 Loss 0.93153673 Correct 53 out of 100
# Step 9754 Loss 0.8488485 Correct 55 out of 100
# Step 9755 Loss 1.0356053 Correct 45 out of 100
# Step 9756 Loss 0.98520494 Correct 49 out of 100
# Step 9757 Loss 0.96403533 Correct 45 out of 100
# Step 9758 Loss 0.85405874 Correct 63 out of 100
# Step 9759 Loss 0.8957126 Correct 53 out of 100
# Step 9760 Loss 0.91605794 Correct 52 out of 100
# Step 9761 Loss 0.9207026 Correct 55 out of 100
# Step 9762 Loss 0.93180525 Correct 49 out of 100
# Step 9763 Loss 0.83196294 Correct 66 out of 100
# Step 9764 Loss 0.881027 Correct 60 out of 100
# Step 9765 Loss 0.80604357 Correct 60 out of 100
# Step 9766 Loss 0.91685027 Correct 60 out of 100
# Step 9767 Loss 0.89418274 Correct 53 out of 100
# Step 9768 Loss 0.8479793 Correct 58 out of 100
# Step 9769 Loss 0.99067175 Correct 49 out of 100
# Step 9770 Loss 0.8274601 Correct 65 out of 100
# Step 9771 Loss 0.8874228 Correct 55 out of 100
# Step 9772 Loss 0.89241683 Correct 56 out of 100
# Step 9773 Loss 0.9180484 Correct 54 out of 100
# Step 9774 Loss 0.72285736 Correct 72 out of 100
# Step 9775 Loss 0.77242243 Correct 57 out of 100
# Step 9776 Loss 0.87260306 Correct 61 out of 100
# Step 9777 Loss 0.859082 Correct 49 out of 100
# Step 9778 Loss 0.93973404 Correct 52 out of 100
# Step 9779 Loss 0.9313358 Correct 57 out of 100
# Step 9780 Loss 0.97034854 Correct 44 out of 100
# Step 9781 Loss 0.81173277 Correct 63 out of 100
# Step 9782 Loss 0.89502245 Correct 57 out of 100
# Step 9783 Loss 0.9310798 Correct 58 out of 100
# Step 9784 Loss 0.8764436 Correct 57 out of 100
# Step 9785 Loss 0.94303864 Correct 56 out of 100
# Step 9786 Loss 0.8327685 Correct 63 out of 100
# Step 9787 Loss 0.82521456 Correct 62 out of 100
# Step 9788 Loss 0.9575447 Correct 46 out of 100
# Step 9789 Loss 0.9472639 Correct 48 out of 100
# Step 9790 Loss 0.9444855 Correct 49 out of 100
# Step 9791 Loss 0.79602873 Correct 61 out of 100
# Step 9792 Loss 0.85054284 Correct 58 out of 100
# Step 9793 Loss 0.8619706 Correct 58 out of 100
# Step 9794 Loss 0.99393964 Correct 53 out of 100
# Step 9795 Loss 0.916446 Correct 56 out of 100
# Step 9796 Loss 0.8918083 Correct 58 out of 100
# Step 9797 Loss 0.89099455 Correct 54 out of 100
# Step 9798 Loss 0.8349363 Correct 66 out of 100
# Step 9799 Loss 0.93725944 Correct 48 out of 100
# Step 9800 Loss 0.9777213 Correct 44 out of 100
# Step 9801 Loss 0.88957214 Correct 60 out of 100
# Step 9802 Loss 0.9136887 Correct 53 out of 100
# Step 9803 Loss 0.92209405 Correct 43 out of 100
# Step 9804 Loss 0.87991494 Correct 57 out of 100
# Step 9805 Loss 0.9082547 Correct 56 out of 100
# Step 9806 Loss 0.9020367 Correct 50 out of 100
# Step 9807 Loss 0.8753336 Correct 58 out of 100
# Step 9808 Loss 0.95386773 Correct 47 out of 100
# Step 9809 Loss 0.80588096 Correct 61 out of 100
# Step 9810 Loss 0.98643035 Correct 50 out of 100
# Step 9811 Loss 0.83953196 Correct 53 out of 100
# Step 9812 Loss 0.8939952 Correct 58 out of 100
# Step 9813 Loss 0.85360694 Correct 58 out of 100
# Step 9814 Loss 0.8517816 Correct 50 out of 100
# Step 9815 Loss 0.8416562 Correct 58 out of 100
# Step 9816 Loss 0.9663675 Correct 49 out of 100
# Step 9817 Loss 0.9478984 Correct 49 out of 100
# Step 9818 Loss 0.88159156 Correct 60 out of 100
# Step 9819 Loss 0.93193054 Correct 57 out of 100
# Step 9820 Loss 0.82471377 Correct 56 out of 100
# Step 9821 Loss 0.94793284 Correct 50 out of 100
# Step 9822 Loss 0.910817 Correct 57 out of 100
# Step 9823 Loss 0.87762976 Correct 54 out of 100
# Step 9824 Loss 0.82857424 Correct 57 out of 100
# Step 9825 Loss 0.95417047 Correct 55 out of 100
# Step 9826 Loss 0.8888275 Correct 59 out of 100
# Step 9827 Loss 0.9231861 Correct 42 out of 100
# Step 9828 Loss 0.93371034 Correct 49 out of 100
# Step 9829 Loss 1.0168464 Correct 41 out of 100
# Step 9830 Loss 0.8160864 Correct 58 out of 100
# Step 9831 Loss 1.0231186 Correct 53 out of 100
# Step 9832 Loss 0.85730445 Correct 55 out of 100
# Step 9833 Loss 0.9538884 Correct 47 out of 100
# Step 9834 Loss 0.99048966 Correct 42 out of 100
# Step 9835 Loss 0.91399854 Correct 57 out of 100
# Step 9836 Loss 0.95985883 Correct 53 out of 100
# Step 9837 Loss 0.8643114 Correct 62 out of 100
# Step 9838 Loss 0.94144 Correct 49 out of 100
# Step 9839 Loss 0.8976986 Correct 52 out of 100
# Step 9840 Loss 0.8287626 Correct 56 out of 100
# Step 9841 Loss 0.91115075 Correct 59 out of 100
# Step 9842 Loss 0.84501296 Correct 60 out of 100
# Step 9843 Loss 0.9361455 Correct 54 out of 100
# Step 9844 Loss 0.95410883 Correct 50 out of 100
# Step 9845 Loss 0.84034705 Correct 56 out of 100
# Step 9846 Loss 0.8736841 Correct 52 out of 100
# Step 9847 Loss 0.8802278 Correct 54 out of 100
# Step 9848 Loss 0.9405867 Correct 48 out of 100
# Step 9849 Loss 0.9246019 Correct 52 out of 100
# Step 9850 Loss 0.965938 Correct 49 out of 100
# Step 9851 Loss 0.86710054 Correct 54 out of 100
# Step 9852 Loss 0.81638855 Correct 61 out of 100
# Step 9853 Loss 0.90105253 Correct 57 out of 100
# Step 9854 Loss 0.81877387 Correct 61 out of 100
# Step 9855 Loss 0.99048185 Correct 48 out of 100
# Step 9856 Loss 0.8948066 Correct 52 out of 100
# Step 9857 Loss 0.9537397 Correct 51 out of 100
# Step 9858 Loss 0.89264035 Correct 52 out of 100
# Step 9859 Loss 0.8735962 Correct 59 out of 100
# Step 9860 Loss 0.85847825 Correct 55 out of 100
# Step 9861 Loss 0.8553579 Correct 53 out of 100
# Step 9862 Loss 0.8495735 Correct 54 out of 100
# Step 9863 Loss 0.88575155 Correct 56 out of 100
# Step 9864 Loss 0.9201725 Correct 54 out of 100
# Step 9865 Loss 0.91160727 Correct 48 out of 100
# Step 9866 Loss 0.93840516 Correct 54 out of 100
# Step 9867 Loss 0.8907715 Correct 50 out of 100
# Step 9868 Loss 0.9563902 Correct 50 out of 100
# Step 9869 Loss 0.8240249 Correct 56 out of 100
# Step 9870 Loss 0.94570976 Correct 54 out of 100
# Step 9871 Loss 0.9451239 Correct 50 out of 100
# Step 9872 Loss 0.9150001 Correct 46 out of 100
# Step 9873 Loss 0.96157455 Correct 50 out of 100
# Step 9874 Loss 1.0758041 Correct 48 out of 100
# Step 9875 Loss 0.89166665 Correct 57 out of 100
# Step 9876 Loss 0.8606778 Correct 56 out of 100
# Step 9877 Loss 0.8632707 Correct 60 out of 100
# Step 9878 Loss 0.844523 Correct 64 out of 100
# Step 9879 Loss 0.86941856 Correct 56 out of 100
# Step 9880 Loss 0.9571928 Correct 48 out of 100
# Step 9881 Loss 0.9128979 Correct 51 out of 100
# Step 9882 Loss 0.8288305 Correct 60 out of 100
# Step 9883 Loss 0.90846246 Correct 61 out of 100
# Step 9884 Loss 0.9367211 Correct 51 out of 100
# Step 9885 Loss 0.9073285 Correct 60 out of 100
# Step 9886 Loss 0.9574989 Correct 51 out of 100
# Step 9887 Loss 0.8995293 Correct 57 out of 100
# Step 9888 Loss 0.9584008 Correct 52 out of 100
# Step 9889 Loss 0.94215286 Correct 60 out of 100
# Step 9890 Loss 0.8534853 Correct 54 out of 100
# Step 9891 Loss 0.7579558 Correct 63 out of 100
# Step 9892 Loss 0.8479533 Correct 56 out of 100
# Step 9893 Loss 0.84924483 Correct 65 out of 100
# Step 9894 Loss 0.8897964 Correct 58 out of 100
# Step 9895 Loss 0.94079095 Correct 56 out of 100
# Step 9896 Loss 0.97077286 Correct 55 out of 100
# Step 9897 Loss 0.9653016 Correct 47 out of 100
# Step 9898 Loss 0.9877633 Correct 49 out of 100
# Step 9899 Loss 0.8989438 Correct 50 out of 100
# Step 9900 Loss 0.8415862 Correct 57 out of 100
# Step 9901 Loss 0.8602401 Correct 67 out of 100
# Step 9902 Loss 0.946033 Correct 52 out of 100
# Step 9903 Loss 0.93201417 Correct 54 out of 100
# Step 9904 Loss 0.8156081 Correct 64 out of 100
# Step 9905 Loss 0.80343896 Correct 62 out of 100
# Step 9906 Loss 1.0474575 Correct 43 out of 100
# Step 9907 Loss 0.9244928 Correct 55 out of 100
# Step 9908 Loss 0.97152627 Correct 50 out of 100
# Step 9909 Loss 0.87101716 Correct 56 out of 100
# Step 9910 Loss 0.950173 Correct 53 out of 100
# Step 9911 Loss 0.8369944 Correct 55 out of 100
# Step 9912 Loss 0.8374183 Correct 62 out of 100
# Step 9913 Loss 0.8421324 Correct 61 out of 100
# Step 9914 Loss 0.97467774 Correct 47 out of 100
# Step 9915 Loss 0.8627807 Correct 56 out of 100
# Step 9916 Loss 0.920285 Correct 54 out of 100
# Step 9917 Loss 0.8804581 Correct 55 out of 100
# Step 9918 Loss 0.8120601 Correct 57 out of 100
# Step 9919 Loss 0.88557863 Correct 55 out of 100
# Step 9920 Loss 0.8632008 Correct 58 out of 100
# Step 9921 Loss 0.8390355 Correct 53 out of 100
# Step 9922 Loss 0.91487074 Correct 56 out of 100
# Step 9923 Loss 0.9331005 Correct 53 out of 100
# Step 9924 Loss 1.008998 Correct 41 out of 100
# Step 9925 Loss 0.8397797 Correct 65 out of 100
# Step 9926 Loss 1.0326068 Correct 49 out of 100
# Step 9927 Loss 0.93894404 Correct 53 out of 100
# Step 9928 Loss 0.9626591 Correct 52 out of 100
# Step 9929 Loss 1.0199974 Correct 46 out of 100
# Step 9930 Loss 0.8800907 Correct 56 out of 100
# Step 9931 Loss 0.81537336 Correct 55 out of 100
# Step 9932 Loss 0.9298981 Correct 54 out of 100
# Step 9933 Loss 0.8071192 Correct 56 out of 100
# Step 9934 Loss 0.93213415 Correct 56 out of 100
# Step 9935 Loss 0.87736803 Correct 55 out of 100
# Step 9936 Loss 0.873812 Correct 57 out of 100
# Step 9937 Loss 0.8247547 Correct 55 out of 100
# Step 9938 Loss 1.0082631 Correct 45 out of 100
# Step 9939 Loss 1.0301952 Correct 45 out of 100
# Step 9940 Loss 0.82550156 Correct 56 out of 100
# Step 9941 Loss 0.9076268 Correct 50 out of 100
# Step 9942 Loss 0.8774615 Correct 53 out of 100
# Step 9943 Loss 0.868991 Correct 58 out of 100
# Step 9944 Loss 0.83322394 Correct 60 out of 100
# Step 9945 Loss 0.91473234 Correct 50 out of 100
# Step 9946 Loss 0.76971376 Correct 61 out of 100
# Step 9947 Loss 0.9804979 Correct 53 out of 100
# Step 9948 Loss 0.89706945 Correct 50 out of 100
# Step 9949 Loss 0.97066844 Correct 49 out of 100
# Step 9950 Loss 0.83078057 Correct 56 out of 100
# Step 9951 Loss 0.9748012 Correct 47 out of 100
# Step 9952 Loss 0.9757704 Correct 47 out of 100
# Step 9953 Loss 0.923624 Correct 47 out of 100
# Step 9954 Loss 0.7917639 Correct 57 out of 100
# Step 9955 Loss 0.8596415 Correct 55 out of 100
# Step 9956 Loss 0.8533841 Correct 53 out of 100
# Step 9957 Loss 0.9212827 Correct 51 out of 100
# Step 9958 Loss 0.9485865 Correct 51 out of 100
# Step 9959 Loss 0.9350929 Correct 53 out of 100
# Step 9960 Loss 0.96406424 Correct 52 out of 100
# Step 9961 Loss 0.96915054 Correct 44 out of 100
# Step 9962 Loss 0.9564037 Correct 53 out of 100
# Step 9963 Loss 0.9024296 Correct 48 out of 100
# Step 9964 Loss 0.9493444 Correct 54 out of 100
# Step 9965 Loss 0.9608558 Correct 53 out of 100
# Step 9966 Loss 0.83289266 Correct 57 out of 100
# Step 9967 Loss 0.8332764 Correct 58 out of 100
# Step 9968 Loss 0.8404565 Correct 57 out of 100
# Step 9969 Loss 0.76842177 Correct 61 out of 100
# Step 9970 Loss 0.9475409 Correct 52 out of 100
# Step 9971 Loss 0.85456145 Correct 55 out of 100
# Step 9972 Loss 0.86377656 Correct 56 out of 100
# Step 9973 Loss 0.8848669 Correct 57 out of 100
# Step 9974 Loss 1.0535303 Correct 53 out of 100
# Step 9975 Loss 0.90172654 Correct 54 out of 100
# Step 9976 Loss 0.9193924 Correct 49 out of 100
# Step 9977 Loss 0.91025865 Correct 56 out of 100
# Step 9978 Loss 0.85679483 Correct 55 out of 100
# Step 9979 Loss 1.1166271 Correct 37 out of 100
# Step 9980 Loss 0.8580181 Correct 62 out of 100
# Step 9981 Loss 0.94302917 Correct 49 out of 100
# Step 9982 Loss 0.9216721 Correct 53 out of 100
# Step 9983 Loss 0.8683553 Correct 55 out of 100
# Step 9984 Loss 0.8443791 Correct 56 out of 100
# Step 9985 Loss 0.8791133 Correct 56 out of 100
# Step 9986 Loss 0.9541446 Correct 55 out of 100
# Step 9987 Loss 0.89322716 Correct 55 out of 100
# Step 9988 Loss 0.98488295 Correct 41 out of 100
# Step 9989 Loss 0.94360805 Correct 52 out of 100
# Step 9990 Loss 0.93674767 Correct 45 out of 100
# Step 9991 Loss 0.88539636 Correct 52 out of 100
# Step 9992 Loss 0.89103144 Correct 52 out of 100
# Step 9993 Loss 0.88853997 Correct 58 out of 100
# Step 9994 Loss 0.842447 Correct 58 out of 100
# Step 9995 Loss 0.8229639 Correct 57 out of 100
# Step 9996 Loss 0.8301384 Correct 56 out of 100
# Step 9997 Loss 0.98576516 Correct 49 out of 100
# Step 9998 Loss 0.91852033 Correct 61 out of 100
# Step 9999 Loss 0.9445354 Correct 52 out of 100
