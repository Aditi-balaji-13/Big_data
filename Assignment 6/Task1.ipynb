# %%
import tensorflow.compat.v1 as tf
import numpy as np
import urllib
tf.compat.v1.disable_eager_execution()

# %%
# the number of iterations to train for
numTrainingIters = 10000

# the number of hidden neurons that hold the state of the RNN
hiddenUnits = 1000

# the number of classes that we are learning over
numClasses = 3

# the number of data points in a batch
batchSize = 100

# %%
# this function takes a dictionary (called data) which contains
# of (dataPointID, (classNumber, matrix)) entries.  Each matrix
# is a sequence of vectors; each vector has a one-hot-encoding of
# an ascii character, and the sequence of vectors corresponds to
# one line of text.  classNumber indicates which file the line of
# text came from.
#
# The argument maxSeqLen is the maximum length of a line of text
# seen so far.  fileName is the name of a file whose contents
# we want to add to data.  classNum is an indicator of the class
# we are going to associate with text from that file.  linesToUse
# tells us how many lines to sample from the file.
#
# The return val is the new maxSeqLen, as well as the new data
# dictionary with the additional lines of text added
def addToData (maxSeqLen, data, fileName, classNum, linesToUse):
    #
    # open the file and read it in
    response = urllib.request.urlopen(fileName)
    content = response.readlines ()
    #
    # sample linesToUse numbers; these will tell us what lines
    # from the text file we will use
    myInts = np.random.randint (0, len(content), linesToUse)
    #
    # i is the key of the next line of text to add to the dictionary
    i = len(data)
    #
    # loop thru and add the lines of text to the dictionary
    for whichLine in myInts.flat:
        #
        # get the line and ignore it if it has nothing in it
        line = content[whichLine].decode("utf-8")
        if line.isspace () or len(line) == 0:
            continue;
        #
        # take note if this is the longest line we've seen
        if len (line) > maxSeqLen:
            maxSeqLen = len (line)
        #
        # create the matrix that will hold this line
        temp = np.zeros((len(line), 256))
        #
        # j is the character we are on
        j = 0
        #
        # loop thru the characters
        for ch in line:
            #
            # non-ascii? ignore
            if ord(ch) >= 256:
                continue
            #
            # one hot!
            temp[j][ord(ch)] = 1
            #
            # move onto the next character
            j = j + 1
            #
        # remember the line of text
        data[i] = (classNum, temp)
        #
        # move onto the next line
        i = i + 1
    #
    # and return the dictionary with the new data
    return (maxSeqLen, data)

# %%
# this function takes as input a data set encoded as a dictionary
# (same encoding as the last function) and pre-pends every line of
# text with empty characters so that each line of text is exactly
# maxSeqLen characters in size
def pad (maxSeqLen, data):
   #
   # loop thru every line of text
   for i in data:
        #
        # access the matrix and the label
        temp = data[i][1]
        label = data[i][0]
        #
        # get the number of chatacters in this line
        len = temp.shape[0]
        #
        # and then pad so the line is the correct length
        padding = np.zeros ((maxSeqLen - len,256))
        data[i] = (label, np.transpose (np.concatenate ((padding, temp), axis = 0)))
   #
   # return the new data set
   return data

# %%
# this generates a new batch of training data of size batchSize from the
# list of lines of text data. This version of generateData is useful for
# an RNN because the data set x is a NumPy array with dimensions
# [batchSize, 256, maxSeqLen]; it can be unstacked into a series of
# matrices containing one-hot character encodings for each data point
# using tf.unstack(inputX, axis=2)
def generateDataRNN (maxSeqLen, data, batchSize = batchSize):
    #
    # randomly sample batchSize lines of text
    myInts = np.random.randint (0, len(data), batchSize)
    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack ([data[i][1] for i in myInts.flat])
    #
    # and stack all of the labels into a vector of labels
    y = np.stack ([np.array((data[i][0])) for i in myInts.flat])
    #
    # return the pair
    return (x, y)

# %%
# this also generates a new batch of training data, but it represents
# the data as a NumPy array with dimensions [batchSize, 256 * maxSeqLen]
# where for each data point, all characters have been appended.  Useful
# for feed-forward network training
def generateDataFeedForward (maxSeqLen, data):
    #
    # randomly sample batchSize lines of text
    myInts = np.random.randint (0, len(data), batchSize)
    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack (data[i][1].flatten () for i in myInts.flat)
    #
    # and stack all of the labels into a vector of labels
    y = np.stack (np.array((data[i][0])) for i in myInts.flat)
    #
    # return the pair
    return (x, y)

# %%
# create the data dictionary
maxSeqLen = 0
data = {}

# load up the three data sets
(maxSeqLen, data) = addToData (maxSeqLen, data, "https://s3.amazonaws.com/chrisjermainebucket/text/Holmes.txt", 0, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "https://s3.amazonaws.com/chrisjermainebucket/text/war.txt", 1, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "https://s3.amazonaws.com/chrisjermainebucket/text/william.txt", 2, 10000)

# pad each entry in the dictionary with empty characters as needed so
# that the sequences are all of the same length
data = pad (maxSeqLen, data)

# %%
num_test = 3000
print(maxSeqLen, len(data))
# Out:
# 81 24945

# %%
def split_data(data, num_test):
    """
    Splits the data into training and testing sets based on the specified test ratio.

    Args:
    data (dict): Dictionary containing the data to split.
    test_ratio (float): Proportion of the dataset to include in the test split.

    Returns:
    tuple: Two dictionaries, the first being the training set and the second the test set.
    """
    # Extract all keys (indices) from the data
    keys = list(data.keys())
    np.random.shuffle(keys)  # Randomly shuffle the keys

    # Split the keys into training and testing
    test_keys = keys[:num_test]
    train_keys = keys[num_test:]

    # Create dictionaries for train and test datasets
    train_data = {i: data[key] for i, key in enumerate(train_keys)}
    test_data = {i: data[key] for i, key in enumerate(test_keys)}

    return train_data, test_data

# %%
# Splitting padded data into Train and Test Data
train_data, test_data = split_data(data, num_test)  # 25% of data as test set

print("Training Set Size:", len(train_data))
print("Test Set Size:", len(test_data))
# Out:
# Training Set Size: 21945
# Test Set Size: 3000

# %%
def find_max_seq_len(data):
    """
    Finds the maximum sequence length in a dataset.

    Args:
    data (dict): Dictionary containing the data, where each entry is a tuple (classNumber, matrix).

    Returns:
    int: The maximum sequence length in the dataset.
    """
    max_len = 0
    for key, value in data.items():
        # value[1] is the matrix, and its sum is maxSeqLen as it is one-hot-encoded
        sequence_length = value[1].sum()
        if sequence_length > max_len:
            max_len = sequence_length
    return int(max_len)

# %%
maxSeqLen_train = find_max_seq_len(train_data)
maxSeqLen_test = find_max_seq_len(test_data)

print("Maximum length of sequence in Training set:", maxSeqLen_train)
print("Maximum length of sequence in Test set:", maxSeqLen_test)
# Out:
# Maximum length of sequence in Training set: 81
# Maximum length of sequence in Test set: 81

# %%
# now we build the TensorFlow computation... there are two inputs,
# a batch of text lines and a batch of labels
inputX = tf.placeholder(tf.float32, [batchSize, 256, maxSeqLen])
inputY = tf.placeholder(tf.int32, [batchSize])

# this is the inital state of the RNN, before processing any data
initialState = tf.placeholder(tf.float32, [batchSize, hiddenUnits])

# the weight matrix that maps the inputs and hidden state to a set of values
Wfir = tf.Variable(np.random.normal(0, 0.01, (hiddenUnits + 256, hiddenUnits)), dtype=tf.float32)
Wsec = tf.Variable(np.random.normal(0, 0.01, (hiddenUnits, hiddenUnits)), dtype=tf.float32)

# weights and bias for the final classification
W2 = tf.Variable(np.random.normal (0, 0.05, (hiddenUnits, numClasses)),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,numClasses)), dtype=tf.float32)

# unpack the input sequences so that we have a series of matrices,
# each of which has a one-hot encoding of the current character from
# every input sequence
sequenceOfLetters = tf.unstack(inputX, axis=2)

# now we implement the forward pass
currentState = initialState
for timeTick in sequenceOfLetters:
    #
    # concatenate the state with the input, then compute the next state
    inputPlusState = tf.concat([timeTick, currentState], 1)
    next_state = tf.tanh(tf.matmul(inputPlusState, Wfir))
    last_state = tf.tanh(tf.matmul(next_state, Wsec))
    currentState = last_state

# compute the set of outputs
outputs = tf.matmul(currentState, W2) + b2

predictions = tf.nn.softmax(outputs)

# compute the loss
losses = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=outputs, labels=inputY)
totalLoss = tf.reduce_mean(losses)

# use gradient descent to train
trainingAlg = tf.compat.v1.train.AdagradOptimizer(0.01).minimize(totalLoss)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/training/adagrad.py:138: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# and train!!
with tf.Session() as sess:
    #
    # initialize everything
    sess.run(tf.compat.v1.global_variables_initializer())
    #
    # and run the training iters
    for epoch in range(numTrainingIters):
        #
        # get some data
        x, y = generateDataRNN (maxSeqLen, train_data,  batchSize=100)
        #
        # do the training epoch
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _trainingAlg, _currentState, _predictions, _outputs = sess.run(
                [totalLoss, trainingAlg, currentState, predictions, outputs],
                feed_dict={
                    inputX:x,
                    inputY:y,
                    initialState:_currentState
                })
        #
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y)):
           maxPos = -1
           maxVal = 0.0
           for j in range (numClasses):
               if maxVal < _predictions[i][j]:
                   maxVal = _predictions[i][j]
                   maxPos = j
           if maxPos == y[i]:
               numCorrect = numCorrect + 1
        #
        # print out to the screen
        print("Step", epoch, "Loss", _totalLoss, "Correct", numCorrect, "out of", batchSize)

    Numtestiter = num_test // batchSize
    test_correct = 0
    totalTestLoss = 0
    xtest, ytest = generateDataRNN(maxSeqLen, test_data, batchSize=num_test)
    for idx in range(Numtestiter):
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _predictions = sess.run(
                [totalLoss, predictions],
                feed_dict={
                    inputX:xtest[(idx*batchSize):((idx+1)*batchSize)],
                    inputY:ytest[(idx*batchSize):((idx+1)*batchSize)],
                    initialState:_currentState
                })

        numCorrect = 0
        for i in range (batchSize):
            maxPos = -1
            maxVal = 0.0
            for j in range (numClasses):
                if maxVal < _predictions[i][j]:
                    maxVal = _predictions[i][j]
                    maxPos = j
            if maxPos == ytest[i]:
                numCorrect = numCorrect + 1

        test_correct += numCorrect
        totalTestLoss += _totalLoss * batchSize

    print(f"Loss for {num_test} test samples is {totalTestLoss / num_test} and correct is {test_correct} out of {num_test}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Step 5001 Loss 1.0897977 Correct 40 out of 100
# Step 5002 Loss 1.0857954 Correct 42 out of 100
# Step 5003 Loss 1.0844831 Correct 42 out of 100
# Step 5004 Loss 1.0990463 Correct 35 out of 100
# Step 5005 Loss 1.0974746 Correct 36 out of 100
# Step 5006 Loss 1.0830343 Correct 44 out of 100
# Step 5007 Loss 1.0871353 Correct 41 out of 100
# Step 5008 Loss 1.0966295 Correct 35 out of 100
# Step 5009 Loss 1.0989879 Correct 36 out of 100
# Step 5010 Loss 1.0900769 Correct 40 out of 100
# Step 5011 Loss 1.1019121 Correct 34 out of 100
# Step 5012 Loss 1.109493 Correct 29 out of 100
# Step 5013 Loss 1.0947247 Correct 38 out of 100
# Step 5014 Loss 1.0948131 Correct 37 out of 100
# Step 5015 Loss 1.1113083 Correct 28 out of 100
# Step 5016 Loss 1.0881692 Correct 41 out of 100
# Step 5017 Loss 1.0882831 Correct 41 out of 100
# Step 5018 Loss 1.0936518 Correct 38 out of 100
# Step 5019 Loss 1.0948324 Correct 37 out of 100
# Step 5020 Loss 1.0899552 Correct 40 out of 100
# Step 5021 Loss 1.0857121 Correct 42 out of 100
# Step 5022 Loss 1.1137654 Correct 27 out of 100
# Step 5023 Loss 1.0991757 Correct 34 out of 100
# Step 5024 Loss 1.0815512 Correct 45 out of 100
# Step 5025 Loss 1.1030316 Correct 32 out of 100
# Step 5026 Loss 1.0935024 Correct 38 out of 100
# Step 5027 Loss 1.0984604 Correct 36 out of 100
# Step 5028 Loss 1.0857027 Correct 41 out of 100
# Step 5029 Loss 1.1054127 Correct 30 out of 100
# Step 5030 Loss 1.1153133 Correct 25 out of 100
# Step 9669 Loss 0.7895624 Correct 61 out of 100
# Step 9670 Loss 0.92914945 Correct 49 out of 100
# Step 9671 Loss 0.84825397 Correct 57 out of 100
# Step 9672 Loss 0.93325317 Correct 58 out of 100
# Step 9673 Loss 0.870421 Correct 57 out of 100
# Step 9674 Loss 0.925341 Correct 51 out of 100
# Step 9675 Loss 0.88778764 Correct 51 out of 100
# Step 9676 Loss 0.946447 Correct 51 out of 100
# Step 9677 Loss 0.98728555 Correct 47 out of 100
# Step 9678 Loss 1.0147204 Correct 44 out of 100
# Step 9679 Loss 0.9444675 Correct 55 out of 100
# Step 9680 Loss 0.845087 Correct 58 out of 100
# Step 9681 Loss 0.81094205 Correct 59 out of 100
# Step 9682 Loss 0.87500525 Correct 58 out of 100
# Step 9683 Loss 0.8861845 Correct 55 out of 100
# Step 9684 Loss 0.89959234 Correct 55 out of 100
# Step 9685 Loss 0.88811904 Correct 50 out of 100
# Step 9686 Loss 0.8836589 Correct 60 out of 100
# Step 9687 Loss 0.9938747 Correct 48 out of 100
# Step 9688 Loss 0.85926646 Correct 52 out of 100
# Step 9689 Loss 0.9284937 Correct 57 out of 100
# Step 9690 Loss 0.99279577 Correct 46 out of 100
# Step 9691 Loss 0.9847916 Correct 50 out of 100
# Step 9692 Loss 0.84209603 Correct 68 out of 100
# Step 9693 Loss 0.9015734 Correct 52 out of 100
# Step 9694 Loss 0.92073023 Correct 55 out of 100
# Step 9695 Loss 0.8610144 Correct 54 out of 100
# Step 9696 Loss 0.9441675 Correct 61 out of 100
# Step 9697 Loss 0.8865054 Correct 51 out of 100
# Step 9698 Loss 0.8687153 Correct 57 out of 100
# Step 9699 Loss 0.95459336 Correct 55 out of 100
# Step 9700 Loss 0.92103255 Correct 62 out of 100
# Step 9701 Loss 1.0318514 Correct 56 out of 100
# Step 9702 Loss 0.8520661 Correct 59 out of 100
# Step 9703 Loss 0.88209236 Correct 53 out of 100
# Step 9704 Loss 0.9569102 Correct 52 out of 100
# Step 9705 Loss 0.9700157 Correct 53 out of 100
# Step 9706 Loss 0.91154635 Correct 54 out of 100
# Step 9707 Loss 0.9021341 Correct 51 out of 100
# Step 9708 Loss 1.0005285 Correct 50 out of 100
# Step 9709 Loss 0.9187574 Correct 55 out of 100
# Step 9710 Loss 0.9321914 Correct 46 out of 100
# Step 9711 Loss 0.9717874 Correct 52 out of 100
# Step 9712 Loss 1.0631804 Correct 43 out of 100
# Step 9713 Loss 0.79778343 Correct 64 out of 100
# Step 9714 Loss 0.95558107 Correct 54 out of 100
# Step 9715 Loss 0.8686294 Correct 58 out of 100
# Step 9716 Loss 0.8806651 Correct 55 out of 100
# Step 9717 Loss 0.91968817 Correct 56 out of 100
# Step 9718 Loss 0.8854559 Correct 54 out of 100
# Step 9719 Loss 0.80460554 Correct 62 out of 100
# Step 9720 Loss 0.92864585 Correct 51 out of 100
# Step 9721 Loss 0.87119436 Correct 60 out of 100
# Step 9722 Loss 0.8998144 Correct 54 out of 100
# Step 9723 Loss 0.96201324 Correct 49 out of 100
# Step 9724 Loss 0.9725723 Correct 50 out of 100
# Step 9725 Loss 0.99395025 Correct 46 out of 100
# Step 9726 Loss 0.89976907 Correct 52 out of 100
# Step 9727 Loss 0.8110092 Correct 59 out of 100
# Step 9728 Loss 0.9650154 Correct 48 out of 100
# Step 9729 Loss 1.0144943 Correct 42 out of 100
# Step 9730 Loss 0.8671039 Correct 52 out of 100
# Step 9731 Loss 0.900019 Correct 52 out of 100
# Step 9732 Loss 0.89803433 Correct 52 out of 100
# Step 9733 Loss 0.9049393 Correct 54 out of 100
# Step 9734 Loss 0.8747702 Correct 59 out of 100
# Step 9735 Loss 0.9156238 Correct 61 out of 100
# Step 9736 Loss 0.8880711 Correct 55 out of 100
# Step 9737 Loss 0.85298294 Correct 58 out of 100
# Step 9738 Loss 0.83544123 Correct 52 out of 100
# Step 9739 Loss 0.93395483 Correct 52 out of 100
# Step 9740 Loss 0.9281977 Correct 58 out of 100
# Step 9741 Loss 1.0402085 Correct 45 out of 100
# Step 9742 Loss 0.8520865 Correct 60 out of 100
# Step 9743 Loss 0.81362295 Correct 59 out of 100
# Step 9744 Loss 0.89480287 Correct 55 out of 100
# Step 9745 Loss 0.9271649 Correct 49 out of 100
# Step 9746 Loss 0.86146957 Correct 58 out of 100
# Step 9747 Loss 0.90585846 Correct 55 out of 100
# Step 9748 Loss 0.9188737 Correct 50 out of 100
# Step 9749 Loss 0.92265725 Correct 55 out of 100
# Step 9750 Loss 0.9275839 Correct 57 out of 100
# Step 9751 Loss 0.922269 Correct 50 out of 100
# Step 9752 Loss 0.8737607 Correct 52 out of 100
# Step 9753 Loss 0.9455499 Correct 49 out of 100
# Step 9754 Loss 0.7747622 Correct 64 out of 100
# Step 9755 Loss 0.9492629 Correct 51 out of 100
# Step 9756 Loss 0.8597568 Correct 54 out of 100
# Step 9757 Loss 0.92611647 Correct 48 out of 100
# Step 9758 Loss 0.9652179 Correct 52 out of 100
# Step 9759 Loss 0.8830158 Correct 56 out of 100
# Step 9760 Loss 0.8228343 Correct 60 out of 100
# Step 9761 Loss 0.9286759 Correct 54 out of 100
# Step 9762 Loss 0.84461 Correct 59 out of 100
# Step 9763 Loss 0.8743821 Correct 58 out of 100
# Step 9764 Loss 0.8796675 Correct 56 out of 100
# Step 9765 Loss 0.9364234 Correct 49 out of 100
# Step 9766 Loss 0.91696084 Correct 54 out of 100
# Step 9767 Loss 1.040797 Correct 46 out of 100
# Step 9768 Loss 0.96681094 Correct 46 out of 100
# Step 9769 Loss 0.93271375 Correct 55 out of 100
# Step 9770 Loss 0.9882112 Correct 50 out of 100
# Step 9771 Loss 0.86183757 Correct 56 out of 100
# Step 9772 Loss 0.86881727 Correct 55 out of 100
# Step 9773 Loss 0.95630014 Correct 45 out of 100
# Step 9774 Loss 0.9090031 Correct 59 out of 100
# Step 9775 Loss 0.92738897 Correct 49 out of 100
# Step 9776 Loss 0.9327829 Correct 56 out of 100
# Step 9777 Loss 0.9398764 Correct 51 out of 100
# Step 9778 Loss 0.99662566 Correct 49 out of 100
# Step 9779 Loss 0.8941655 Correct 55 out of 100
# Step 9780 Loss 0.9106551 Correct 53 out of 100
# Step 9781 Loss 0.9651898 Correct 49 out of 100
# Step 9782 Loss 0.88947564 Correct 53 out of 100
# Step 9783 Loss 0.96660346 Correct 50 out of 100
# Step 9784 Loss 0.997055 Correct 47 out of 100
# Step 9785 Loss 0.9944242 Correct 51 out of 100
# Step 9786 Loss 0.79924554 Correct 59 out of 100
# Step 9787 Loss 0.9177616 Correct 60 out of 100
# Step 9788 Loss 0.82553 Correct 59 out of 100
# Step 9789 Loss 0.96909773 Correct 45 out of 100
# Step 9790 Loss 0.83951926 Correct 55 out of 100
# Step 9791 Loss 0.93821394 Correct 57 out of 100
# Step 9792 Loss 0.92293763 Correct 50 out of 100
# Step 9793 Loss 0.89674205 Correct 57 out of 100
# Step 9794 Loss 0.9618895 Correct 52 out of 100
# Step 9795 Loss 0.89643306 Correct 58 out of 100
# Step 9796 Loss 0.82006973 Correct 64 out of 100
# Step 9797 Loss 0.9528729 Correct 56 out of 100
# Step 9798 Loss 0.942863 Correct 57 out of 100
# Step 9799 Loss 0.9023141 Correct 56 out of 100
# Step 9800 Loss 0.9736799 Correct 42 out of 100
# Step 9801 Loss 0.90310663 Correct 49 out of 100
# Step 9802 Loss 0.8448928 Correct 64 out of 100
# Step 9803 Loss 0.9324677 Correct 57 out of 100
# Step 9804 Loss 0.96483696 Correct 56 out of 100
# Step 9805 Loss 0.89343435 Correct 48 out of 100
# Step 9806 Loss 0.8193302 Correct 65 out of 100
# Step 9807 Loss 0.9450523 Correct 52 out of 100
# Step 9808 Loss 0.9033084 Correct 50 out of 100
# Step 9809 Loss 1.0071152 Correct 49 out of 100
# Step 9810 Loss 0.8885463 Correct 55 out of 100
# Step 9811 Loss 0.9310606 Correct 56 out of 100
# Step 9812 Loss 0.8473587 Correct 56 out of 100
# Step 9813 Loss 0.9828745 Correct 51 out of 100
# Step 9814 Loss 0.9318934 Correct 52 out of 100
# Step 9815 Loss 0.8201654 Correct 64 out of 100
# Step 9816 Loss 1.0046992 Correct 47 out of 100
# Step 9817 Loss 0.897001 Correct 52 out of 100
# Step 9818 Loss 0.93921393 Correct 54 out of 100
# Step 9819 Loss 0.9414122 Correct 56 out of 100
# Step 9820 Loss 0.8780698 Correct 62 out of 100
# Step 9821 Loss 0.97173744 Correct 47 out of 100
# Step 9822 Loss 0.810494 Correct 58 out of 100
# Step 9823 Loss 0.8578034 Correct 56 out of 100
# Step 9824 Loss 0.88035864 Correct 61 out of 100
# Step 9825 Loss 0.96138215 Correct 48 out of 100
# Step 9826 Loss 0.8677161 Correct 57 out of 100
# Step 9827 Loss 0.98648626 Correct 58 out of 100
# Step 9828 Loss 0.91756654 Correct 56 out of 100
# Step 9829 Loss 0.9235023 Correct 55 out of 100
# Step 9830 Loss 0.95264107 Correct 58 out of 100
# Step 9831 Loss 0.85261863 Correct 51 out of 100
# Step 9832 Loss 0.87992674 Correct 57 out of 100
# Step 9833 Loss 0.8316683 Correct 62 out of 100
# Step 9834 Loss 0.8484211 Correct 60 out of 100
# Step 9835 Loss 0.861209 Correct 53 out of 100
# Step 9836 Loss 0.8558596 Correct 55 out of 100
# Step 9837 Loss 0.9434264 Correct 51 out of 100
# Step 9838 Loss 0.9014857 Correct 50 out of 100
# Step 9839 Loss 0.908442 Correct 51 out of 100
# Step 9840 Loss 0.93165797 Correct 47 out of 100
# Step 9841 Loss 0.9755241 Correct 56 out of 100
# Step 9842 Loss 0.9660948 Correct 47 out of 100
# Step 9843 Loss 0.9147709 Correct 51 out of 100
# Step 9844 Loss 0.90876305 Correct 49 out of 100
# Step 9845 Loss 0.89037997 Correct 50 out of 100
# Step 9846 Loss 0.85512686 Correct 57 out of 100
# Step 9847 Loss 0.9488893 Correct 48 out of 100
# Step 9848 Loss 0.87714255 Correct 53 out of 100
# Step 9849 Loss 0.9026912 Correct 52 out of 100
# Step 9850 Loss 0.8998599 Correct 56 out of 100
# Step 9851 Loss 0.99542737 Correct 45 out of 100
# Step 9852 Loss 1.0672667 Correct 45 out of 100
# Step 9853 Loss 0.8704355 Correct 62 out of 100
# Step 9854 Loss 0.967935 Correct 46 out of 100
# Step 9855 Loss 0.9229242 Correct 54 out of 100
# Step 9856 Loss 0.94874734 Correct 48 out of 100
# Step 9857 Loss 0.9851162 Correct 50 out of 100
# Step 9858 Loss 0.8614883 Correct 58 out of 100
# Step 9859 Loss 0.86699647 Correct 66 out of 100
# Step 9860 Loss 0.94199944 Correct 52 out of 100
# Step 9861 Loss 0.9275242 Correct 53 out of 100
# Step 9862 Loss 0.8792981 Correct 59 out of 100
# Step 9863 Loss 0.9960464 Correct 40 out of 100
# Step 9864 Loss 0.9425972 Correct 48 out of 100
# Step 9865 Loss 0.8976158 Correct 61 out of 100
# Step 9866 Loss 0.9621814 Correct 50 out of 100
# Step 9867 Loss 0.89058477 Correct 61 out of 100
# Step 9868 Loss 0.8777957 Correct 58 out of 100
# Step 9869 Loss 0.8512365 Correct 58 out of 100
# Step 9870 Loss 0.8709251 Correct 60 out of 100
# Step 9871 Loss 0.9387313 Correct 56 out of 100
# Step 9872 Loss 0.9511056 Correct 49 out of 100
# Step 9873 Loss 0.90674233 Correct 59 out of 100
# Step 9874 Loss 0.89642173 Correct 48 out of 100
# Step 9875 Loss 0.92832506 Correct 57 out of 100
# Step 9876 Loss 0.88102937 Correct 55 out of 100
# Step 9877 Loss 0.90914094 Correct 51 out of 100
# Step 9878 Loss 0.83357626 Correct 65 out of 100
# Step 9879 Loss 0.8915018 Correct 55 out of 100
# Step 9880 Loss 0.96823287 Correct 52 out of 100
# Step 9881 Loss 0.9378584 Correct 49 out of 100
# Step 9882 Loss 0.9186521 Correct 60 out of 100
# Step 9883 Loss 0.8965699 Correct 50 out of 100
# Step 9884 Loss 0.89895034 Correct 55 out of 100
# Step 9885 Loss 1.0145447 Correct 55 out of 100
# Step 9886 Loss 0.9326786 Correct 54 out of 100
# Step 9887 Loss 0.874096 Correct 58 out of 100
# Step 9888 Loss 0.952861 Correct 48 out of 100
# Step 9889 Loss 0.9422487 Correct 49 out of 100
# Step 9890 Loss 0.8764812 Correct 53 out of 100
# Step 9891 Loss 0.8806973 Correct 52 out of 100
# Step 9892 Loss 0.8759136 Correct 56 out of 100
# Step 9893 Loss 0.90317273 Correct 55 out of 100
# Step 9894 Loss 0.88567 Correct 54 out of 100
# Step 9895 Loss 0.93066454 Correct 55 out of 100
# Step 9896 Loss 0.86462617 Correct 56 out of 100
# Step 9897 Loss 0.72500235 Correct 64 out of 100
# Step 9898 Loss 0.948304 Correct 54 out of 100
# Step 9899 Loss 0.929526 Correct 50 out of 100
# Step 9900 Loss 0.86626565 Correct 55 out of 100
# Step 9901 Loss 1.1344707 Correct 44 out of 100
# Step 9902 Loss 0.9091609 Correct 52 out of 100
# Step 9903 Loss 0.9647754 Correct 48 out of 100
# Step 9904 Loss 0.9441176 Correct 52 out of 100
# Step 9905 Loss 1.0097712 Correct 45 out of 100
# Step 9906 Loss 0.80696315 Correct 67 out of 100
# Step 9907 Loss 0.8730724 Correct 52 out of 100
# Step 9908 Loss 0.95633906 Correct 52 out of 100
# Step 9909 Loss 0.86257726 Correct 58 out of 100
# Step 9910 Loss 0.96098936 Correct 49 out of 100
# Step 9911 Loss 0.8727714 Correct 57 out of 100
# Step 9912 Loss 0.887923 Correct 55 out of 100
# Step 9913 Loss 1.1064657 Correct 45 out of 100
# Step 9914 Loss 1.0213456 Correct 44 out of 100
# Step 9915 Loss 0.8715874 Correct 56 out of 100
# Step 9916 Loss 0.9021808 Correct 53 out of 100
# Step 9917 Loss 0.94838023 Correct 57 out of 100
# Step 9918 Loss 0.91783625 Correct 55 out of 100
# Step 9919 Loss 0.9083159 Correct 50 out of 100
# Step 9920 Loss 1.0178341 Correct 48 out of 100
# Step 9921 Loss 0.91914076 Correct 53 out of 100
# Step 9922 Loss 0.8521717 Correct 55 out of 100
# Step 9923 Loss 0.9566018 Correct 45 out of 100
# Step 9924 Loss 0.97913176 Correct 46 out of 100
# Step 9925 Loss 0.880228 Correct 63 out of 100
# Step 9926 Loss 0.9885508 Correct 50 out of 100
# Step 9927 Loss 0.8462099 Correct 56 out of 100
# Step 9928 Loss 0.8282609 Correct 61 out of 100
# Step 9929 Loss 1.020555 Correct 46 out of 100
# Step 9930 Loss 0.8888307 Correct 54 out of 100
# Step 9931 Loss 0.9141919 Correct 53 out of 100
# Step 9932 Loss 0.8754656 Correct 55 out of 100
# Step 9933 Loss 0.95542926 Correct 50 out of 100
# Step 9934 Loss 0.93073404 Correct 46 out of 100
# Step 9935 Loss 0.9313112 Correct 52 out of 100
# Step 9936 Loss 0.86645705 Correct 58 out of 100
# Step 9937 Loss 0.9028535 Correct 53 out of 100
# Step 9938 Loss 0.8404298 Correct 55 out of 100
# Step 9939 Loss 0.93834597 Correct 50 out of 100
# Step 9940 Loss 0.83612365 Correct 60 out of 100
# Step 9941 Loss 0.934514 Correct 55 out of 100
# Step 9942 Loss 0.90508074 Correct 52 out of 100
# Step 9943 Loss 0.93193126 Correct 54 out of 100
# Step 9944 Loss 0.96886414 Correct 49 out of 100
# Step 9945 Loss 0.93315256 Correct 52 out of 100
# Step 9946 Loss 0.9168962 Correct 54 out of 100
# Step 9947 Loss 0.7963775 Correct 63 out of 100
# Step 9948 Loss 0.85433286 Correct 56 out of 100
# Step 9949 Loss 0.9684949 Correct 51 out of 100
# Step 9950 Loss 0.8923455 Correct 55 out of 100
# Step 9951 Loss 0.99731225 Correct 49 out of 100
# Step 9952 Loss 0.8461266 Correct 63 out of 100
# Step 9953 Loss 0.93058854 Correct 42 out of 100
# Step 9954 Loss 0.9265978 Correct 55 out of 100
# Step 9955 Loss 0.9150249 Correct 51 out of 100
# Step 9956 Loss 0.8750866 Correct 56 out of 100
# Step 9957 Loss 0.7981681 Correct 62 out of 100
# Step 9958 Loss 0.8902954 Correct 52 out of 100
# Step 9959 Loss 0.9312126 Correct 52 out of 100
# Step 9960 Loss 0.92047364 Correct 53 out of 100
# Step 9961 Loss 0.9815036 Correct 49 out of 100
# Step 9962 Loss 0.9116449 Correct 51 out of 100
# Step 9963 Loss 0.8641465 Correct 58 out of 100
# Step 9964 Loss 0.7897914 Correct 62 out of 100
# Step 9965 Loss 0.8660347 Correct 63 out of 100
# Step 9966 Loss 0.892141 Correct 49 out of 100
# Step 9967 Loss 1.007283 Correct 49 out of 100
# Step 9968 Loss 1.0105499 Correct 46 out of 100
# Step 9969 Loss 0.8413179 Correct 62 out of 100
# Step 9970 Loss 0.96782416 Correct 52 out of 100
# Step 9971 Loss 0.8369718 Correct 52 out of 100
# Step 9972 Loss 0.8054902 Correct 57 out of 100
# Step 9973 Loss 0.97625077 Correct 49 out of 100
# Step 9974 Loss 0.9000241 Correct 45 out of 100
# Step 9975 Loss 0.87034166 Correct 60 out of 100
# Step 9976 Loss 0.9862095 Correct 52 out of 100
# Step 9977 Loss 0.9268829 Correct 55 out of 100
# Step 9978 Loss 0.8630878 Correct 57 out of 100
# Step 9979 Loss 0.96287847 Correct 52 out of 100
# Step 9980 Loss 0.91967475 Correct 51 out of 100
# Step 9981 Loss 0.89893705 Correct 48 out of 100
# Step 9982 Loss 0.94406337 Correct 50 out of 100
# Step 9983 Loss 0.876957 Correct 57 out of 100
# Step 9984 Loss 0.87101793 Correct 52 out of 100
# Step 9985 Loss 0.8780482 Correct 57 out of 100
# Step 9986 Loss 0.9152413 Correct 51 out of 100
# Step 9987 Loss 0.8947532 Correct 56 out of 100
# Step 9988 Loss 0.91460145 Correct 51 out of 100
# Step 9989 Loss 0.93708396 Correct 50 out of 100
# Step 9990 Loss 0.92268854 Correct 54 out of 100
# Step 9991 Loss 0.8329005 Correct 56 out of 100
# Step 9992 Loss 1.041201 Correct 53 out of 100
# Step 9993 Loss 0.8680583 Correct 55 out of 100
# Step 9994 Loss 0.96103144 Correct 51 out of 100
# Step 9995 Loss 0.9278388 Correct 53 out of 100
# Step 9996 Loss 0.9495953 Correct 58 out of 100
# Step 9997 Loss 0.9139567 Correct 56 out of 100
# Step 9998 Loss 0.9686182 Correct 53 out of 100
# Step 9999 Loss 0.95999277 Correct 55 out of 100
# Loss for 3000 test samples is 0.9098752260208129 and correct is 1052 out of 3000
