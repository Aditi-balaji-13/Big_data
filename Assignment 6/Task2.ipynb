# %%
import tensorflow.compat.v1 as tf
import numpy as np
import urllib
from collections import deque
tf.compat.v1.disable_eager_execution()

# %%
# the number of iterations to train for
numTrainingIters = 10000

# the number of hidden neurons that hold the state of the RNN
hiddenUnits = 1000

# the number of classes that we are learning over
numClasses = 3

# the number of data points in a batch
batchSize = 100

# %%
# this function takes a dictionary (called data) which contains
# of (dataPointID, (classNumber, matrix)) entries.  Each matrix
# is a sequence of vectors; each vector has a one-hot-encoding of
# an ascii character, and the sequence of vectors corresponds to
# one line of text.  classNumber indicates which file the line of
# text came from.
#
# The argument maxSeqLen is the maximum length of a line of text
# seen so far.  fileName is the name of a file whose contents
# we want to add to data.  classNum is an indicator of the class
# we are going to associate with text from that file.  linesToUse
# tells us how many lines to sample from the file.
#
# The return val is the new maxSeqLen, as well as the new data
# dictionary with the additional lines of text added
def addToData (maxSeqLen, data, fileName, classNum, linesToUse):
    #
    # open the file and read it in
    response = urllib.request.urlopen(fileName)
    content = response.readlines ()
    #
    # sample linesToUse numbers; these will tell us what lines
    # from the text file we will use
    myInts = np.random.randint (0, len(content), linesToUse)
    #
    # i is the key of the next line of text to add to the dictionary
    i = len(data)
    #
    # loop thru and add the lines of text to the dictionary
    for whichLine in myInts.flat:
        #
        # get the line and ignore it if it has nothing in it
        line = content[whichLine].decode("utf-8")
        if line.isspace () or len(line) == 0:
            continue;
        #
        # take note if this is the longest line we've seen
        if len (line) > maxSeqLen:
            maxSeqLen = len (line)
        #
        # create the matrix that will hold this line
        temp = np.zeros((len(line), 256))
        #
        # j is the character we are on
        j = 0
        #
        # loop thru the characters
        for ch in line:
            #
            # non-ascii? ignore
            if ord(ch) >= 256:
                continue
            #
            # one hot!
            temp[j][ord(ch)] = 1
            #
            # move onto the next character
            j = j + 1
            #
        # remember the line of text
        data[i] = (classNum, temp)
        #
        # move onto the next line
        i = i + 1
    #
    # and return the dictionary with the new data
    return (maxSeqLen, data)

# %%
# this function takes as input a data set encoded as a dictionary
# (same encoding as the last function) and pre-pends every line of
# text with empty characters so that each line of text is exactly
# maxSeqLen characters in size
def pad (maxSeqLen, data):
   #
   # loop thru every line of text
   for i in data:
        #
        # access the matrix and the label
        temp = data[i][1]
        label = data[i][0]
        #
        # get the number of chatacters in this line
        len = temp.shape[0]
        #
        # and then pad so the line is the correct length
        padding = np.zeros ((maxSeqLen - len,256))
        data[i] = (label, np.transpose (np.concatenate ((padding, temp), axis = 0)))
   #
   # return the new data set
   return data

# %%
# this generates a new batch of training data of size batchSize from the
# list of lines of text data. This version of generateData is useful for
# an RNN because the data set x is a NumPy array with dimensions
# [batchSize, 256, maxSeqLen]; it can be unstacked into a series of
# matrices containing one-hot character encodings for each data point
# using tf.unstack(inputX, axis=2)
def generateDataRNN (maxSeqLen, data, batchSize = batchSize):
    #
    # randomly sample batchSize lines of text
    myInts = np.random.randint (0, len(data), batchSize)
    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack ([data[i][1] for i in myInts.flat])
    #
    # and stack all of the labels into a vector of labels
    y = np.stack ([np.array((data[i][0])) for i in myInts.flat])
    #
    # return the pair
    return (x, y)

# %%
# this also generates a new batch of training data, but it represents
# the data as a NumPy array with dimensions [batchSize, 256 * maxSeqLen]
# where for each data point, all characters have been appended.  Useful
# for feed-forward network training
def generateDataFeedForward (maxSeqLen, data):
    #
    # randomly sample batchSize lines of text
    myInts = np.random.randint (0, len(data), batchSize)
    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack (data[i][1].flatten () for i in myInts.flat)
    #
    # and stack all of the labels into a vector of labels
    y = np.stack (np.array((data[i][0])) for i in myInts.flat)
    #
    # return the pair
    return (x, y)

# %%
# create the data dictionary
maxSeqLen = 0
data = {}

# load up the three data sets
(maxSeqLen, data) = addToData (maxSeqLen, data, "https://s3.amazonaws.com/chrisjermainebucket/text/Holmes.txt", 0, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "https://s3.amazonaws.com/chrisjermainebucket/text/war.txt", 1, 10000)
(maxSeqLen, data) = addToData (maxSeqLen, data, "https://s3.amazonaws.com/chrisjermainebucket/text/william.txt", 2, 10000)

# pad each entry in the dictionary with empty characters as needed so
# that the sequences are all of the same length
data = pad (maxSeqLen, data)

# %%
num_test = 3000
print(maxSeqLen, len(data))
# Out:
# 83 24948

# %%
def split_data(data, num_test):
    """
    Splits the data into training and testing sets based on the specified test ratio.

    Args:
    data (dict): Dictionary containing the data to split.
    test_ratio (float): Proportion of the dataset to include in the test split.

    Returns:
    tuple: Two dictionaries, the first being the training set and the second the test set.
    """
    # Extract all keys (indices) from the data
    keys = list(data.keys())
    np.random.shuffle(keys)  # Randomly shuffle the keys

    # Split the keys into training and testing
    test_keys = keys[:num_test]
    train_keys = keys[num_test:]

    # Create dictionaries for train and test datasets
    train_data = {i: data[key] for i, key in enumerate(train_keys)}
    test_data = {i: data[key] for i, key in enumerate(test_keys)}

    return train_data, test_data

# %%
# Splitting padded data into Train and Test Data
train_data, test_data = split_data(data, num_test)  # 25% of data as test set

print("Training Set Size:", len(train_data))
print("Test Set Size:", len(test_data))
# Out:
# Training Set Size: 21948
# Test Set Size: 3000

# %%
def find_max_seq_len(data):
    """
    Finds the maximum sequence length in a dataset.

    Args:
    data (dict): Dictionary containing the data, where each entry is a tuple (classNumber, matrix).

    Returns:
    int: The maximum sequence length in the dataset.
    """
    max_len = 0
    for key, value in data.items():
        # value[1] is the matrix, and its sum is maxSeqLen as it is one-hot-encoded
        sequence_length = value[1].sum()
        if sequence_length > max_len:
            max_len = sequence_length
    return int(max_len)

# %%
maxSeqLen_train = find_max_seq_len(train_data)
maxSeqLen_test = find_max_seq_len(test_data)

print("Maximum length of sequence in Training set:", maxSeqLen_train)
print("Maximum length of sequence in Test set:", maxSeqLen_test)
# Out:
# Maximum length of sequence in Training set: 83
# Maximum length of sequence in Test set: 75

# %%
# now we build the TensorFlow computation... there are two inputs,
# a batch of text lines and a batch of labels
inputX = tf.placeholder(tf.float32, [batchSize, 256, maxSeqLen])
inputY = tf.placeholder(tf.int32, [batchSize])

# this is the inital state of the RNN, before processing any data
initialState = tf.placeholder(tf.float32, [batchSize, hiddenUnits])

# the weight matrix that maps the inputs and hidden state to a set of values
Wfir = tf.Variable(np.random.normal(0, 0.01, (hiddenUnits+ hiddenUnits + 256, hiddenUnits)), dtype=tf.float32)
Wsec = tf.Variable(np.random.normal(0, 0.01, (hiddenUnits, hiddenUnits)), dtype=tf.float32)

# weights and bias for the final classification
W2 = tf.Variable(np.random.normal (0, 0.05, (hiddenUnits, numClasses)),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,numClasses)), dtype=tf.float32)

# unpack the input sequences so that we have a series of matrices,
# each of which has a one-hot encoding of the current character from
# every input sequence
sequenceOfLetters = tf.unstack(inputX, axis=2)
window = deque()
window.extend([initialState]*10)

# now we implement the forward pass
currentState = initialState
for timeTick in sequenceOfLetters:
    warp = window.popleft()
    #
    # concatenate the state with the input, then compute the next state
    inputPlusState = tf.concat([timeTick, currentState, warp], 1)
    next_state = tf.tanh(tf.matmul(inputPlusState, Wfir))
    last_state = tf.tanh(tf.matmul(next_state, Wsec))
    window.append(next_state)
    currentState = last_state

# compute the set of outputs
outputs = tf.matmul(currentState, W2) + b2

predictions = tf.nn.softmax(outputs)

# compute the loss
losses = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=outputs, labels=inputY)
totalLoss = tf.reduce_mean(losses)

# use gradient descent to train
trainingAlg = tf.compat.v1.train.AdagradOptimizer(0.01).minimize(totalLoss)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/training/adagrad.py:138: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# and train!!
with tf.Session() as sess:
    #
    # initialize everything
    sess.run(tf.compat.v1.global_variables_initializer())
    #
    # and run the training iters
    for epoch in range(numTrainingIters):
        #
        # get some data
        x, y = generateDataRNN (maxSeqLen, train_data,  batchSize=100)
        #
        # do the training epoch
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _trainingAlg, _currentState, _predictions, _outputs = sess.run(
                [totalLoss, trainingAlg, currentState, predictions, outputs],
                feed_dict={
                    inputX:x,
                    inputY:y,
                    initialState:_currentState
                })
        #
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y)):
           maxPos = -1
           maxVal = 0.0
           for j in range (numClasses):
               if maxVal < _predictions[i][j]:
                   maxVal = _predictions[i][j]
                   maxPos = j
           if maxPos == y[i]:
               numCorrect = numCorrect + 1
        #
        # print out to the screen
        print("Step", epoch, "Loss", _totalLoss, "Correct", numCorrect, "out of", batchSize)

    Numtestiter = num_test // batchSize
    test_correct = 0
    totalTestLoss = 0
    xtest, ytest = generateDataRNN(maxSeqLen, test_data, batchSize=num_test)
    for idx in range(Numtestiter):
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _predictions = sess.run(
                [totalLoss, predictions],
                feed_dict={
                    inputX:xtest[(idx*batchSize):((idx+1)*batchSize)],
                    inputY:ytest[(idx*batchSize):((idx+1)*batchSize)],
                    initialState:_currentState
                })

        numCorrect = 0
        for i in range (batchSize):
            maxPos = -1
            maxVal = 0.0
            for j in range (numClasses):
                if maxVal < _predictions[i][j]:
                    maxVal = _predictions[i][j]
                    maxPos = j
            if maxPos == ytest[i]:
                numCorrect = numCorrect + 1

        test_correct += numCorrect
        totalTestLoss += _totalLoss * batchSize

    print(f"Loss for {num_test} test samples is {totalTestLoss / num_test} and correct is {test_correct} out of {num_test}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Step 5001 Loss 0.39070305 Correct 82 out of 100
# Step 5002 Loss 0.4174475 Correct 77 out of 100
# Step 5003 Loss 0.48792174 Correct 80 out of 100
# Step 5004 Loss 0.4221227 Correct 83 out of 100
# Step 5005 Loss 0.27920666 Correct 89 out of 100
# Step 5006 Loss 0.35130516 Correct 86 out of 100
# Step 5007 Loss 0.29062307 Correct 89 out of 100
# Step 5008 Loss 0.33792818 Correct 87 out of 100
# Step 5009 Loss 0.27458993 Correct 87 out of 100
# Step 5010 Loss 0.25096858 Correct 94 out of 100
# Step 5011 Loss 0.24154165 Correct 91 out of 100
# Step 5012 Loss 0.24128315 Correct 95 out of 100
# Step 5013 Loss 0.3978706 Correct 79 out of 100
# Step 5014 Loss 0.41696647 Correct 84 out of 100
# Step 5015 Loss 0.34956935 Correct 88 out of 100
# Step 5016 Loss 0.38268414 Correct 83 out of 100
# Step 5017 Loss 0.3394798 Correct 85 out of 100
# Step 5018 Loss 0.26903677 Correct 88 out of 100
# Step 5019 Loss 0.21515864 Correct 91 out of 100
# Step 5020 Loss 0.29163703 Correct 87 out of 100
# Step 5021 Loss 0.33177516 Correct 88 out of 100
# Step 5022 Loss 0.27285942 Correct 88 out of 100
# Step 5023 Loss 0.2940899 Correct 94 out of 100
# Step 5024 Loss 0.39872402 Correct 80 out of 100
# Step 5025 Loss 0.38306028 Correct 87 out of 100
# Step 5026 Loss 0.22475386 Correct 94 out of 100
# Step 5027 Loss 0.26991677 Correct 91 out of 100
# Step 5028 Loss 0.23861343 Correct 93 out of 100
# Step 9674 Loss 0.30382976 Correct 86 out of 100
# Step 9675 Loss 0.28781486 Correct 85 out of 100
# Step 9676 Loss 0.30236387 Correct 84 out of 100
# Step 9677 Loss 0.19400251 Correct 89 out of 100
# Step 9678 Loss 0.20984341 Correct 91 out of 100
# Step 9679 Loss 0.13489595 Correct 92 out of 100
# Step 9680 Loss 0.39383972 Correct 83 out of 100
# Step 9681 Loss 0.19248086 Correct 89 out of 100
# Step 9682 Loss 0.23760389 Correct 88 out of 100
# Step 9683 Loss 0.23952381 Correct 91 out of 100
# Step 9684 Loss 0.17998335 Correct 92 out of 100
# Step 9685 Loss 0.17883268 Correct 88 out of 100
# Step 9686 Loss 0.14803949 Correct 93 out of 100
# Step 9687 Loss 0.19980954 Correct 95 out of 100
# Step 9688 Loss 0.33904904 Correct 92 out of 100
# Step 9689 Loss 0.18275528 Correct 94 out of 100
# Step 9690 Loss 0.30159768 Correct 86 out of 100
# Step 9691 Loss 0.18836634 Correct 93 out of 100
# Step 9692 Loss 0.12927176 Correct 95 out of 100
# Step 9693 Loss 0.19017507 Correct 90 out of 100
# Step 9694 Loss 0.18400158 Correct 92 out of 100
# Step 9695 Loss 0.20415424 Correct 91 out of 100
# Step 9696 Loss 0.22111592 Correct 91 out of 100
# Step 9697 Loss 0.2468697 Correct 90 out of 100
# Step 9698 Loss 0.22040156 Correct 89 out of 100
# Step 9699 Loss 0.2356786 Correct 91 out of 100
# Step 9700 Loss 0.24850845 Correct 90 out of 100
# Step 9701 Loss 0.23000422 Correct 90 out of 100
# Step 9702 Loss 0.2946649 Correct 91 out of 100
# Step 9703 Loss 0.27139464 Correct 85 out of 100
# Step 9704 Loss 0.25409862 Correct 92 out of 100
# Step 9705 Loss 0.23496887 Correct 87 out of 100
# Step 9706 Loss 0.20289448 Correct 92 out of 100
# Step 9707 Loss 0.18363386 Correct 93 out of 100
# Step 9708 Loss 0.24237666 Correct 92 out of 100
# Step 9709 Loss 0.220659 Correct 87 out of 100
# Step 9710 Loss 0.3005508 Correct 90 out of 100
# Step 9711 Loss 0.34745914 Correct 89 out of 100
# Step 9712 Loss 0.16150354 Correct 94 out of 100
# Step 9713 Loss 0.20715673 Correct 90 out of 100
# Step 9714 Loss 0.34429228 Correct 85 out of 100
# Step 9715 Loss 0.30755097 Correct 84 out of 100
# Step 9716 Loss 0.24651794 Correct 94 out of 100
# Step 9717 Loss 0.3172214 Correct 89 out of 100
# Step 9718 Loss 0.2562413 Correct 89 out of 100
# Step 9719 Loss 0.17984004 Correct 90 out of 100
# Step 9720 Loss 0.17534189 Correct 96 out of 100
# Step 9721 Loss 0.21748698 Correct 88 out of 100
# Step 9722 Loss 0.17293508 Correct 92 out of 100
# Step 9723 Loss 0.23337357 Correct 90 out of 100
# Step 9724 Loss 0.19531763 Correct 92 out of 100
# Step 9725 Loss 0.23892044 Correct 89 out of 100
# Step 9726 Loss 0.23895684 Correct 92 out of 100
# Step 9727 Loss 0.3670905 Correct 89 out of 100
# Step 9728 Loss 0.3286502 Correct 87 out of 100
# Step 9729 Loss 0.21957743 Correct 91 out of 100
# Step 9730 Loss 0.19190401 Correct 89 out of 100
# Step 9731 Loss 0.29573628 Correct 89 out of 100
# Step 9732 Loss 0.16733976 Correct 93 out of 100
# Step 9733 Loss 0.26214188 Correct 85 out of 100
# Step 9734 Loss 0.1666746 Correct 94 out of 100
# Step 9735 Loss 0.23962966 Correct 89 out of 100
# Step 9736 Loss 0.2994509 Correct 91 out of 100
# Step 9737 Loss 0.31789225 Correct 84 out of 100
# Step 9738 Loss 0.2624464 Correct 88 out of 100
# Step 9739 Loss 0.23836748 Correct 90 out of 100
# Step 9740 Loss 0.25635594 Correct 86 out of 100
# Step 9741 Loss 0.20398788 Correct 91 out of 100
# Step 9742 Loss 0.13801247 Correct 95 out of 100
# Step 9743 Loss 0.08668161 Correct 98 out of 100
# Step 9744 Loss 0.2362588 Correct 91 out of 100
# Step 9745 Loss 0.23904227 Correct 89 out of 100
# Step 9746 Loss 0.2262089 Correct 90 out of 100
# Step 9747 Loss 0.26121247 Correct 86 out of 100
# Step 9748 Loss 0.22527601 Correct 93 out of 100
# Step 9749 Loss 0.20533997 Correct 93 out of 100
# Step 9750 Loss 0.28012463 Correct 90 out of 100
# Step 9751 Loss 0.13696185 Correct 96 out of 100
# Step 9752 Loss 0.22313797 Correct 91 out of 100
# Step 9753 Loss 0.3178743 Correct 86 out of 100
# Step 9754 Loss 0.1808696 Correct 94 out of 100
# Step 9755 Loss 0.1560273 Correct 89 out of 100
# Step 9756 Loss 0.2560184 Correct 90 out of 100
# Step 9757 Loss 0.24334681 Correct 90 out of 100
# Step 9758 Loss 0.2140022 Correct 93 out of 100
# Step 9759 Loss 0.21002184 Correct 90 out of 100
# Step 9760 Loss 0.38691002 Correct 89 out of 100
# Step 9761 Loss 0.2575079 Correct 86 out of 100
# Step 9762 Loss 0.2564939 Correct 92 out of 100
# Step 9763 Loss 0.256891 Correct 91 out of 100
# Step 9764 Loss 0.18780513 Correct 93 out of 100
# Step 9765 Loss 0.2898474 Correct 89 out of 100
# Step 9766 Loss 0.22816257 Correct 89 out of 100
# Step 9767 Loss 0.13534735 Correct 97 out of 100
# Step 9768 Loss 0.23112823 Correct 89 out of 100
# Step 9769 Loss 0.2937249 Correct 87 out of 100
# Step 9770 Loss 0.22073686 Correct 91 out of 100
# Step 9771 Loss 0.1719917 Correct 90 out of 100
# Step 9772 Loss 0.22873837 Correct 89 out of 100
# Step 9773 Loss 0.25501588 Correct 84 out of 100
# Step 9774 Loss 0.2898276 Correct 87 out of 100
# Step 9775 Loss 0.21901794 Correct 92 out of 100
# Step 9776 Loss 0.23236202 Correct 92 out of 100
# Step 9777 Loss 0.25532126 Correct 88 out of 100
# Step 9778 Loss 0.32625848 Correct 86 out of 100
# Step 9779 Loss 0.32756653 Correct 87 out of 100
# Step 9780 Loss 0.1943602 Correct 94 out of 100
# Step 9781 Loss 0.26643258 Correct 91 out of 100
# Step 9782 Loss 0.16309002 Correct 94 out of 100
# Step 9783 Loss 0.3398051 Correct 89 out of 100
# Step 9784 Loss 0.25954953 Correct 89 out of 100
# Step 9785 Loss 0.24584505 Correct 90 out of 100
# Step 9786 Loss 0.18399704 Correct 94 out of 100
# Step 9787 Loss 0.30792576 Correct 87 out of 100
# Step 9788 Loss 0.21644379 Correct 90 out of 100
# Step 9789 Loss 0.26410383 Correct 90 out of 100
# Step 9790 Loss 0.17745388 Correct 95 out of 100
# Step 9791 Loss 0.29914942 Correct 87 out of 100
# Step 9792 Loss 0.2922462 Correct 85 out of 100
# Step 9793 Loss 0.24399525 Correct 89 out of 100
# Step 9794 Loss 0.22753248 Correct 90 out of 100
# Step 9795 Loss 0.22129282 Correct 88 out of 100
# Step 9796 Loss 0.26250368 Correct 87 out of 100
# Step 9797 Loss 0.2687346 Correct 91 out of 100
# Step 9798 Loss 0.31192705 Correct 88 out of 100
# Step 9799 Loss 0.29317302 Correct 89 out of 100
# Step 9800 Loss 0.18173946 Correct 93 out of 100
# Step 9801 Loss 0.20843433 Correct 89 out of 100
# Step 9802 Loss 0.19053611 Correct 95 out of 100
# Step 9803 Loss 0.22918989 Correct 91 out of 100
# Step 9804 Loss 0.27107978 Correct 92 out of 100
# Step 9805 Loss 0.2974696 Correct 90 out of 100
# Step 9806 Loss 0.2759122 Correct 90 out of 100
# Step 9807 Loss 0.2397593 Correct 92 out of 100
# Step 9808 Loss 0.33855435 Correct 87 out of 100
# Step 9809 Loss 0.30862674 Correct 84 out of 100
# Step 9810 Loss 0.26025653 Correct 90 out of 100
# Step 9811 Loss 0.35511452 Correct 87 out of 100
# Step 9812 Loss 0.18244088 Correct 91 out of 100
# Step 9813 Loss 0.27044758 Correct 85 out of 100
# Step 9814 Loss 0.18961558 Correct 88 out of 100
# Step 9815 Loss 0.23149769 Correct 89 out of 100
# Step 9816 Loss 0.2526815 Correct 86 out of 100
# Step 9817 Loss 0.2976702 Correct 90 out of 100
# Step 9818 Loss 0.14482519 Correct 93 out of 100
# Step 9819 Loss 0.1961945 Correct 93 out of 100
# Step 9820 Loss 0.190408 Correct 93 out of 100
# Step 9821 Loss 0.3185322 Correct 85 out of 100
# Step 9822 Loss 0.2291862 Correct 87 out of 100
# Step 9823 Loss 0.19253111 Correct 93 out of 100
# Step 9824 Loss 0.2788295 Correct 90 out of 100
# Step 9825 Loss 0.18746437 Correct 89 out of 100
# Step 9826 Loss 0.17624904 Correct 93 out of 100
# Step 9827 Loss 0.26960945 Correct 90 out of 100
# Step 9828 Loss 0.15090683 Correct 96 out of 100
# Step 9829 Loss 0.21085386 Correct 92 out of 100
# Step 9830 Loss 0.30850762 Correct 87 out of 100
# Step 9831 Loss 0.25415826 Correct 89 out of 100
# Step 9832 Loss 0.3981942 Correct 80 out of 100
# Step 9833 Loss 0.19885854 Correct 89 out of 100
# Step 9834 Loss 0.2949211 Correct 88 out of 100
# Step 9835 Loss 0.16552773 Correct 90 out of 100
# Step 9836 Loss 0.17504494 Correct 95 out of 100
# Step 9837 Loss 0.2325744 Correct 90 out of 100
# Step 9838 Loss 0.28543147 Correct 91 out of 100
# Step 9839 Loss 0.18186516 Correct 94 out of 100
# Step 9840 Loss 0.22348648 Correct 92 out of 100
# Step 9841 Loss 0.28828397 Correct 90 out of 100
# Step 9842 Loss 0.20219778 Correct 91 out of 100
# Step 9843 Loss 0.19564545 Correct 89 out of 100
# Step 9844 Loss 0.15463662 Correct 92 out of 100
# Step 9845 Loss 0.21682754 Correct 93 out of 100
# Step 9846 Loss 0.3509659 Correct 83 out of 100
# Step 9847 Loss 0.35601792 Correct 86 out of 100
# Step 9848 Loss 0.36248156 Correct 85 out of 100
# Step 9849 Loss 0.2367199 Correct 89 out of 100
# Step 9850 Loss 0.18907492 Correct 89 out of 100
# Step 9851 Loss 0.23307091 Correct 88 out of 100
# Step 9852 Loss 0.35131705 Correct 85 out of 100
# Step 9853 Loss 0.2225277 Correct 89 out of 100
# Step 9854 Loss 0.23422873 Correct 91 out of 100
# Step 9855 Loss 0.25643733 Correct 89 out of 100
# Step 9856 Loss 0.16056138 Correct 93 out of 100
# Step 9857 Loss 0.345036 Correct 88 out of 100
# Step 9858 Loss 0.3125779 Correct 85 out of 100
# Step 9859 Loss 0.23799904 Correct 90 out of 100
# Step 9860 Loss 0.20645367 Correct 94 out of 100
# Step 9861 Loss 0.28970754 Correct 87 out of 100
# Step 9862 Loss 0.31224394 Correct 86 out of 100
# Step 9863 Loss 0.16518027 Correct 95 out of 100
# Step 9864 Loss 0.25569984 Correct 89 out of 100
# Step 9865 Loss 0.30042312 Correct 90 out of 100
# Step 9866 Loss 0.3292171 Correct 86 out of 100
# Step 9867 Loss 0.28466007 Correct 89 out of 100
# Step 9868 Loss 0.27573347 Correct 92 out of 100
# Step 9869 Loss 0.24137658 Correct 89 out of 100
# Step 9870 Loss 0.29246315 Correct 89 out of 100
# Step 9871 Loss 0.25990298 Correct 91 out of 100
# Step 9872 Loss 4.1236367 Correct 43 out of 100
# Step 9873 Loss 4.466078 Correct 22 out of 100
# Step 9874 Loss 1.5720471 Correct 36 out of 100
# Step 9875 Loss 1.1570572 Correct 42 out of 100
# Step 9876 Loss 1.0725329 Correct 41 out of 100
# Step 9877 Loss 0.95192045 Correct 40 out of 100
# Step 9878 Loss 1.0014563 Correct 49 out of 100
# Step 9879 Loss 1.0112026 Correct 43 out of 100
# Step 9880 Loss 0.92260575 Correct 47 out of 100
# Step 9881 Loss 0.947253 Correct 54 out of 100
# Step 9882 Loss 0.90106606 Correct 49 out of 100
# Step 9883 Loss 0.9141889 Correct 61 out of 100
# Step 9884 Loss 0.84514546 Correct 54 out of 100
# Step 9885 Loss 0.7456654 Correct 66 out of 100
# Step 9886 Loss 0.73072565 Correct 68 out of 100
# Step 9887 Loss 0.67804646 Correct 70 out of 100
# Step 9888 Loss 0.69987345 Correct 66 out of 100
# Step 9889 Loss 0.6108101 Correct 69 out of 100
# Step 9890 Loss 0.5200558 Correct 75 out of 100
# Step 9891 Loss 0.46022826 Correct 80 out of 100
# Step 9892 Loss 0.6109286 Correct 62 out of 100
# Step 9893 Loss 0.53087157 Correct 75 out of 100
# Step 9894 Loss 0.4397741 Correct 77 out of 100
# Step 9895 Loss 0.3223854 Correct 85 out of 100
# Step 9896 Loss 0.47965577 Correct 78 out of 100
# Step 9897 Loss 0.3135415 Correct 90 out of 100
# Step 9898 Loss 0.42934564 Correct 80 out of 100
# Step 9899 Loss 0.44263843 Correct 80 out of 100
# Step 9900 Loss 0.35817108 Correct 81 out of 100
# Step 9901 Loss 0.39943254 Correct 83 out of 100
# Step 9902 Loss 0.3707453 Correct 90 out of 100
# Step 9903 Loss 0.42894155 Correct 85 out of 100
# Step 9904 Loss 0.32592365 Correct 87 out of 100
# Step 9905 Loss 0.34075856 Correct 86 out of 100
# Step 9906 Loss 0.29921734 Correct 87 out of 100
# Step 9907 Loss 0.34498638 Correct 81 out of 100
# Step 9908 Loss 0.4392843 Correct 77 out of 100
# Step 9909 Loss 0.52692485 Correct 77 out of 100
# Step 9910 Loss 0.7271326 Correct 69 out of 100
# Step 9911 Loss 0.39433777 Correct 81 out of 100
# Step 9912 Loss 0.49676082 Correct 75 out of 100
# Step 9913 Loss 0.34255275 Correct 86 out of 100
# Step 9914 Loss 0.37784672 Correct 83 out of 100
# Step 9915 Loss 0.34399873 Correct 87 out of 100
# Step 9916 Loss 0.32692516 Correct 87 out of 100
# Step 9917 Loss 0.32572615 Correct 85 out of 100
# Step 9918 Loss 0.40511584 Correct 79 out of 100
# Step 9919 Loss 0.63324 Correct 68 out of 100
# Step 9920 Loss 0.42103454 Correct 79 out of 100
# Step 9921 Loss 0.4957112 Correct 75 out of 100
# Step 9922 Loss 0.31853932 Correct 85 out of 100
# Step 9923 Loss 0.36991116 Correct 80 out of 100
# Step 9924 Loss 0.39532936 Correct 78 out of 100
# Step 9925 Loss 0.34029213 Correct 87 out of 100
# Step 9926 Loss 0.23081507 Correct 90 out of 100
# Step 9927 Loss 0.32150635 Correct 85 out of 100
# Step 9928 Loss 0.36996406 Correct 87 out of 100
# Step 9929 Loss 0.32886687 Correct 86 out of 100
# Step 9930 Loss 0.47334123 Correct 77 out of 100
# Step 9931 Loss 0.38039714 Correct 82 out of 100
# Step 9932 Loss 0.37588757 Correct 86 out of 100
# Step 9933 Loss 0.27916935 Correct 87 out of 100
# Step 9934 Loss 0.47068334 Correct 85 out of 100
# Step 9935 Loss 0.35303527 Correct 87 out of 100
# Step 9936 Loss 0.3740064 Correct 87 out of 100
# Step 9937 Loss 0.30128044 Correct 89 out of 100
# Step 9938 Loss 0.27943465 Correct 88 out of 100
# Step 9939 Loss 0.3078464 Correct 87 out of 100
# Step 9940 Loss 0.54608667 Correct 75 out of 100
# Step 9941 Loss 0.6685396 Correct 64 out of 100
# Step 9942 Loss 0.39504722 Correct 82 out of 100
# Step 9943 Loss 0.2842034 Correct 90 out of 100
# Step 9944 Loss 0.2847481 Correct 89 out of 100
# Step 9945 Loss 0.30784386 Correct 84 out of 100
# Step 9946 Loss 0.35333017 Correct 83 out of 100
# Step 9947 Loss 0.4392543 Correct 83 out of 100
# Step 9948 Loss 0.2856418 Correct 86 out of 100
# Step 9949 Loss 0.42100394 Correct 83 out of 100
# Step 9950 Loss 0.2942986 Correct 89 out of 100
# Step 9951 Loss 0.3731608 Correct 85 out of 100
# Step 9952 Loss 0.24833888 Correct 91 out of 100
# Step 9953 Loss 0.2443923 Correct 91 out of 100
# Step 9954 Loss 0.20604281 Correct 91 out of 100
# Step 9955 Loss 0.47384384 Correct 79 out of 100
# Step 9956 Loss 0.35656387 Correct 82 out of 100
# Step 9957 Loss 0.56586105 Correct 78 out of 100
# Step 9958 Loss 0.67989 Correct 65 out of 100
# Step 9959 Loss 0.68258667 Correct 66 out of 100
# Step 9960 Loss 0.57026523 Correct 73 out of 100
# Step 9961 Loss 0.48456195 Correct 68 out of 100
# Step 9962 Loss 0.4812928 Correct 77 out of 100
# Step 9963 Loss 0.48945618 Correct 80 out of 100
# Step 9964 Loss 0.49727032 Correct 83 out of 100
# Step 9965 Loss 0.4044585 Correct 79 out of 100
# Step 9966 Loss 0.3922081 Correct 88 out of 100
# Step 9967 Loss 0.37440392 Correct 86 out of 100
# Step 9968 Loss 0.38846806 Correct 86 out of 100
# Step 9969 Loss 0.39905968 Correct 85 out of 100
# Step 9970 Loss 0.2565427 Correct 93 out of 100
# Step 9971 Loss 0.27081048 Correct 89 out of 100
# Step 9972 Loss 0.38766477 Correct 81 out of 100
# Step 9973 Loss 0.3592258 Correct 80 out of 100
# Step 9974 Loss 0.48449272 Correct 79 out of 100
# Step 9975 Loss 0.25690994 Correct 89 out of 100
# Step 9976 Loss 0.44181383 Correct 78 out of 100
# Step 9977 Loss 0.43015125 Correct 73 out of 100
# Step 9978 Loss 0.29724193 Correct 84 out of 100
# Step 9979 Loss 0.41167653 Correct 81 out of 100
# Step 9980 Loss 0.31389537 Correct 89 out of 100
# Step 9981 Loss 0.22544132 Correct 92 out of 100
# Step 9982 Loss 0.26482686 Correct 90 out of 100
# Step 9983 Loss 0.26350653 Correct 88 out of 100
# Step 9984 Loss 0.2609463 Correct 89 out of 100
# Step 9985 Loss 0.31521752 Correct 87 out of 100
# Step 9986 Loss 0.304245 Correct 87 out of 100
# Step 9987 Loss 0.29701123 Correct 84 out of 100
# Step 9988 Loss 0.35741946 Correct 86 out of 100
# Step 9989 Loss 0.2734455 Correct 90 out of 100
# Step 9990 Loss 0.3476155 Correct 80 out of 100
# Step 9991 Loss 0.27266222 Correct 90 out of 100
# Step 9992 Loss 0.36451903 Correct 86 out of 100
# Step 9993 Loss 0.42742538 Correct 86 out of 100
# Step 9994 Loss 0.32521334 Correct 88 out of 100
# Step 9995 Loss 0.39866382 Correct 86 out of 100
# Step 9996 Loss 0.35982853 Correct 83 out of 100
# Step 9997 Loss 0.2622911 Correct 88 out of 100
# Step 9998 Loss 0.19966662 Correct 92 out of 100
# Step 9999 Loss 0.2949425 Correct 87 out of 100
# Loss for 3000 test samples is 0.3201973646879196 and correct is 1092 out of 3000
